# %%
from sklearn import tree
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
# SQL Alchemy
from sqlalchemy import create_engine

# %%
# Create Engine for employee db
#engine = create_engine('postgres://sxwlsbsllohawb:4723d0dab89d2da6bf1aae12930fd6865874a185e4e4dca60e5af580ccd1a185@ec2-52-200-48-116.compute-1.amazonaws.com:5432/d7shhrp5hdjs4d')
engine = create_engine('postgresql://swain:db@localhost:5432/world_happiness')
connection = engine.connect()

# %%
indicators_df = pd.read_sql("SELECT * from table9_2017", connection)
                              
indicators_df.head()
# Out:
#    countryname                                      indicatorname  year_2017  \
# 0  Afghanistan  Age dependency ratio (% of working-age populat...  86.000753
# 1  Afghanistan               Birth rate, crude (per 1,000 people)  33.211000
# 2  Afghanistan  Contributing family workers, female (% of fema...  68.609001
# 3  Afghanistan  Employers, female (% of female employment) (mo...   2.186000
# 4  Afghanistan  Employers, male (% of male employment) (modele...   2.730000
#
#   target_groups
# 0      Very Sad
# 1      Very Sad
# 2      Very Sad
# 3      Very Sad
# 4      Very Sad

# %%
pivot_df = indicators_df.pivot(index='countryname', columns='indicatorname', values='year_2017')

# %%
pivot_df.head()
# Out:
# indicatorname  Age dependency ratio (% of working-age population)  \
# countryname
# Afghanistan                                            86.000753
# Albania                                                45.682097
# Algeria                                                55.804001
# Angola                                                 96.820228
# Argentina                                              56.046355
#
# indicatorname  Birth rate, crude (per 1,000 people)  \
# countryname
# Afghanistan                                  33.211
# Albania                                      11.934
# Algeria                                      24.846
# Angola                                       41.281
# Argentina                                    17.205
#
# indicatorname  Contributing family workers, female (% of female employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            68.609001
# Albania                                                38.580002
# Algeria                                                 2.419000
# Angola                                                 10.554000
# Argentina                                               0.977000
#
# indicatorname  Employers, female (% of female employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                                2.186
# Albania                                                    0.992
# Algeria                                                    2.045
# Angola                                                     2.560
# Argentina                                                  2.461
#
# indicatorname  Employers, male (% of male employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                                2.730
# Albania                                                    3.498
# Algeria                                                    5.108
# Angola                                                     5.876
# Argentina                                                  4.822
#
# indicatorname  Employers, total (% of total employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                                2.620
# Albania                                                    2.445
# Algeria                                                    4.619
# Angola                                                     4.219
# Argentina                                                  3.834
#
# indicatorname  Employment in agriculture (% of total employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            43.988998
# Albania                                                38.203999
# Algeria                                                10.160000
# Angola                                                 50.557999
# Argentina                                               0.059000
#
# indicatorname  Employment in agriculture, female (% of female employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            66.218002
# Albania                                                42.542000
# Algeria                                                 3.841000
# Angola                                                 56.988998
# Argentina                                               0.015000
#
# indicatorname  Employment in industry, female (% of female employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            24.278999
# Albania                                                15.132000
# Algeria                                                24.360001
# Angola                                                  1.134000
# Argentina                                               9.166000
#
# indicatorname  Employment in services (% of total employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            37.985001
# Albania                                                42.444000
# Algeria                                                58.848999
# Angola                                                 41.070999
# Argentina                                              77.503998
#
# indicatorname  ...  Secure Internet servers (per 1 million people)  \
# countryname    ...
# Afghanistan    ...                                       43.447835
# Albania        ...                                      443.020376
# Algeria        ...                                       63.325702
# Angola         ...                                       10.799300
# Argentina      ...                                     1628.591391
#
# indicatorname  Self-employed, female (% of female employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            92.448998
# Albania                                                55.702000
# Algeria                                                25.400999
# Angola                                                 82.555000
# Argentina                                              21.454000
#
# indicatorname  Self-employed, total (% of total employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            82.449997
# Albania                                                57.193001
# Algeria                                                31.731001
# Angola                                                 70.625999
# Argentina                                              25.340000
#
# indicatorname  Sex ratio at birth (male births per female births)  \
# countryname
# Afghanistan                                                1.060
# Albania                                                    1.086
# Algeria                                                    1.050
# Angola                                                     1.030
# Argentina                                                  1.040
#
# indicatorname  Survival to age 65, female (% of cohort)  \
# countryname
# Afghanistan                                   67.574376
# Albania                                       91.145395
# Algeria                                       85.829405
# Angola                                        63.665746
# Argentina                                     86.900558
#
# indicatorname  Survival to age 65, male (% of cohort)  \
# countryname
# Afghanistan                                 60.950303
# Albania                                     84.702788
# Algeria                                     81.889538
# Angola                                      50.634695
# Argentina                                   76.722114
#
# indicatorname  Unemployment, female (% of female labor force) (modeled ILO estimate)  \
# countryname
# Afghanistan                                               14.090
# Albania                                                   12.563
# Algeria                                                   21.114
# Angola                                                     7.467
# Argentina                                                  9.464
#
# indicatorname  Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# countryname
# Afghanistan                                               10.416
# Albania                                                   14.590
# Algeria                                                   10.021
# Angola                                                     6.769
# Argentina                                                  7.527
#
# indicatorname  Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# countryname
# Afghanistan                                               11.184
# Albania                                                   13.750
# Algeria                                                   11.996
# Angola                                                     7.119
# Argentina                                                  8.347
#
# indicatorname  Urban population (% of total population)
# countryname
# Afghanistan                                      25.250
# Albania                                          59.383
# Algeria                                          72.052
# Angola                                           64.839
# Argentina                                        91.749
#
# [5 rows x 35 columns]

# %%
pivot_df=pivot_df.dropna(how='any')

# %%
pivot_df.count()
# Out:
# indicatorname
# Age dependency ratio (% of working-age population)                                               151
# Birth rate, crude (per 1,000 people)                                                             151
# Contributing family workers, female (% of female employment) (modeled ILO estimate)              151
# Employers, female (% of female employment) (modeled ILO estimate)                                151
# Employers, male (% of male employment) (modeled ILO estimate)                                    151
# Employers, total (% of total employment) (modeled ILO estimate)                                  151
# Employment in agriculture (% of total employment) (modeled ILO estimate)                         151
# Employment in agriculture, female (% of female employment) (modeled ILO estimate)                151
# Employment in industry, female (% of female employment) (modeled ILO estimate)                   151
# Employment in services (% of total employment) (modeled ILO estimate)                            151
# Employment in services, female (% of female employment) (modeled ILO estimate)                   151
# Employment to population ratio, 15+, male (%) (modeled ILO estimate)                             151
# Fertility rate, total (births per woman)                                                         151
# GDP per capita (current US$)                                                                     151
# Incidence of tuberculosis (per 100,000 people)                                                   151
# Individuals using the Internet (% of population)                                                 151
# Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate)      151
# Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)    151
# Life expectancy at birth, female (years)                                                         151
# Life expectancy at birth, male (years)                                                           151
# Life expectancy at birth, total (years)                                                          151
# Merchandise exports by the reporting economy (current US$)                                       151
# Merchandise exports to high-income economies (% of total merchandise exports)                    151
# Net migration                                                                                    151
# Rural population (% of total population)                                                         151
# Secure Internet servers (per 1 million people)                                                   151
# Self-employed, female (% of female employment) (modeled ILO estimate)                            151
# Self-employed, total (% of total employment) (modeled ILO estimate)                              151
# Sex ratio at birth (male births per female births)                                               151
# Survival to age 65, female (% of cohort)                                                         151
# Survival to age 65, male (% of cohort)                                                           151
# Unemployment, female (% of female labor force) (modeled ILO estimate)                            151
# Unemployment, male (% of male labor force) (modeled ILO estimate)                                151
# Unemployment, total (% of total labor force) (modeled ILO estimate)                              151
# Urban population (% of total population)                                                         151
# dtype: int64

# %%
target_groups_df = pd.read_sql("SELECT distinct countryname,target_groups  from table9_2017", connection)
                              
target_groups_df.head()
# Out:
#   countryname    target_groups
# 0      Angola         Very Sad
# 1     Ireland  Extremely Happy
# 2      Malawi         Very Sad
# 3      Rwanda         Very Sad
# 4     Denmark  Extremely Happy

# %%
merged_df = pd.merge(pivot_df, target_groups_df 
                   ,left_on="countryname"
                   ,right_on = "countryname"
                   ,how="inner")

# %%
merged_df.head()
# Out:
#    countryname  Age dependency ratio (% of working-age population)  \
# 0  Afghanistan                                          86.000753
# 1      Albania                                          45.682097
# 2      Algeria                                          55.804001
# 3       Angola                                          96.820228
# 4    Argentina                                          56.046355
#
#    Birth rate, crude (per 1,000 people)  \
# 0                                33.211
# 1                                11.934
# 2                                24.846
# 3                                41.281
# 4                                17.205
#
#    Contributing family workers, female (% of female employment) (modeled ILO estimate)  \
# 0                                          68.609001
# 1                                          38.580002
# 2                                           2.419000
# 3                                          10.554000
# 4                                           0.977000
#
#    Employers, female (% of female employment) (modeled ILO estimate)  \
# 0                                              2.186
# 1                                              0.992
# 2                                              2.045
# 3                                              2.560
# 4                                              2.461
#
#    Employers, male (% of male employment) (modeled ILO estimate)  \
# 0                                              2.730
# 1                                              3.498
# 2                                              5.108
# 3                                              5.876
# 4                                              4.822
#
#    Employers, total (% of total employment) (modeled ILO estimate)  \
# 0                                              2.620
# 1                                              2.445
# 2                                              4.619
# 3                                              4.219
# 4                                              3.834
#
#    Employment in agriculture (% of total employment) (modeled ILO estimate)  \
# 0                                          43.988998
# 1                                          38.203999
# 2                                          10.160000
# 3                                          50.557999
# 4                                           0.059000
#
#    Employment in agriculture, female (% of female employment) (modeled ILO estimate)  \
# 0                                          66.218002
# 1                                          42.542000
# 2                                           3.841000
# 3                                          56.988998
# 4                                           0.015000
#
#    Employment in industry, female (% of female employment) (modeled ILO estimate)  \
# 0                                          24.278999
# 1                                          15.132000
# 2                                          24.360001
# 3                                           1.134000
# 4                                           9.166000
#
#    ...  Self-employed, female (% of female employment) (modeled ILO estimate)  \
# 0  ...                                          92.448998
# 1  ...                                          55.702000
# 2  ...                                          25.400999
# 3  ...                                          82.555000
# 4  ...                                          21.454000
#
#    Self-employed, total (% of total employment) (modeled ILO estimate)  \
# 0                                          82.449997
# 1                                          57.193001
# 2                                          31.731001
# 3                                          70.625999
# 4                                          25.340000
#
#    Sex ratio at birth (male births per female births)  \
# 0                                              1.060
# 1                                              1.086
# 2                                              1.050
# 3                                              1.030
# 4                                              1.040
#
#    Survival to age 65, female (% of cohort)  \
# 0                                 67.574376
# 1                                 91.145395
# 2                                 85.829405
# 3                                 63.665746
# 4                                 86.900558
#
#    Survival to age 65, male (% of cohort)  \
# 0                               60.950303
# 1                               84.702788
# 2                               81.889538
# 3                               50.634695
# 4                               76.722114
#
#    Unemployment, female (% of female labor force) (modeled ILO estimate)  \
# 0                                             14.090
# 1                                             12.563
# 2                                             21.114
# 3                                              7.467
# 4                                              9.464
#
#    Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# 0                                             10.416
# 1                                             14.590
# 2                                             10.021
# 3                                              6.769
# 4                                              7.527
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                             11.184
# 1                                             13.750
# 2                                             11.996
# 3                                              7.119
# 4                                              8.347
#
#    Urban population (% of total population)     target_groups
# 0                                    25.250          Very Sad
# 1                                    59.383    Moderately Sad
# 2                                    72.052  Moderately Happy
# 3                                    64.839          Very Sad
# 4                                    91.749   Extremely Happy
#
# [5 rows x 37 columns]

# %%
target = merged_df["target_groups"]
target.head()
# Out:
# 0            Very Sad
# 1      Moderately Sad
# 2    Moderately Happy
# 3            Very Sad
# 4     Extremely Happy
# Name: target_groups, dtype: object

# %%
target_names = pd.read_sql("SELECT distinct target_groups  from table9_2017", connection)
target_names
# Out:
#       target_groups
# 0   Extremely Happy
# 1         Apathetic
# 2  Moderately Happy
# 3    Moderately Sad
# 4          Very Sad

# %%
data = merged_df.drop(["target_groups","countryname"], axis=1)

# %%
feature_names = data.columns
data.head()
# Out:
#    Age dependency ratio (% of working-age population)  \
# 0                                          86.000753
# 1                                          45.682097
# 2                                          55.804001
# 3                                          96.820228
# 4                                          56.046355
#
#    Birth rate, crude (per 1,000 people)  \
# 0                                33.211
# 1                                11.934
# 2                                24.846
# 3                                41.281
# 4                                17.205
#
#    Contributing family workers, female (% of female employment) (modeled ILO estimate)  \
# 0                                          68.609001
# 1                                          38.580002
# 2                                           2.419000
# 3                                          10.554000
# 4                                           0.977000
#
#    Employers, female (% of female employment) (modeled ILO estimate)  \
# 0                                              2.186
# 1                                              0.992
# 2                                              2.045
# 3                                              2.560
# 4                                              2.461
#
#    Employers, male (% of male employment) (modeled ILO estimate)  \
# 0                                              2.730
# 1                                              3.498
# 2                                              5.108
# 3                                              5.876
# 4                                              4.822
#
#    Employers, total (% of total employment) (modeled ILO estimate)  \
# 0                                              2.620
# 1                                              2.445
# 2                                              4.619
# 3                                              4.219
# 4                                              3.834
#
#    Employment in agriculture (% of total employment) (modeled ILO estimate)  \
# 0                                          43.988998
# 1                                          38.203999
# 2                                          10.160000
# 3                                          50.557999
# 4                                           0.059000
#
#    Employment in agriculture, female (% of female employment) (modeled ILO estimate)  \
# 0                                          66.218002
# 1                                          42.542000
# 2                                           3.841000
# 3                                          56.988998
# 4                                           0.015000
#
#    Employment in industry, female (% of female employment) (modeled ILO estimate)  \
# 0                                          24.278999
# 1                                          15.132000
# 2                                          24.360001
# 3                                           1.134000
# 4                                           9.166000
#
#    Employment in services (% of total employment) (modeled ILO estimate)  ...  \
# 0                                          37.985001                      ...
# 1                                          42.444000                      ...
# 2                                          58.848999                      ...
# 3                                          41.070999                      ...
# 4                                          77.503998                      ...
#
#    Secure Internet servers (per 1 million people)  \
# 0                                       43.447835
# 1                                      443.020376
# 2                                       63.325702
# 3                                       10.799300
# 4                                     1628.591391
#
#    Self-employed, female (% of female employment) (modeled ILO estimate)  \
# 0                                          92.448998
# 1                                          55.702000
# 2                                          25.400999
# 3                                          82.555000
# 4                                          21.454000
#
#    Self-employed, total (% of total employment) (modeled ILO estimate)  \
# 0                                          82.449997
# 1                                          57.193001
# 2                                          31.731001
# 3                                          70.625999
# 4                                          25.340000
#
#    Sex ratio at birth (male births per female births)  \
# 0                                              1.060
# 1                                              1.086
# 2                                              1.050
# 3                                              1.030
# 4                                              1.040
#
#    Survival to age 65, female (% of cohort)  \
# 0                                 67.574376
# 1                                 91.145395
# 2                                 85.829405
# 3                                 63.665746
# 4                                 86.900558
#
#    Survival to age 65, male (% of cohort)  \
# 0                               60.950303
# 1                               84.702788
# 2                               81.889538
# 3                               50.634695
# 4                               76.722114
#
#    Unemployment, female (% of female labor force) (modeled ILO estimate)  \
# 0                                             14.090
# 1                                             12.563
# 2                                             21.114
# 3                                              7.467
# 4                                              9.464
#
#    Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# 0                                             10.416
# 1                                             14.590
# 2                                             10.021
# 3                                              6.769
# 4                                              7.527
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                             11.184
# 1                                             13.750
# 2                                             11.996
# 3                                              7.119
# 4                                              8.347
#
#    Urban population (% of total population)
# 0                                    25.250
# 1                                    59.383
# 2                                    72.052
# 3                                    64.839
# 4                                    91.749
#
# [5 rows x 35 columns]

# %%
data.count()
# Out:
# Age dependency ratio (% of working-age population)                                               151
# Birth rate, crude (per 1,000 people)                                                             151
# Contributing family workers, female (% of female employment) (modeled ILO estimate)              151
# Employers, female (% of female employment) (modeled ILO estimate)                                151
# Employers, male (% of male employment) (modeled ILO estimate)                                    151
# Employers, total (% of total employment) (modeled ILO estimate)                                  151
# Employment in agriculture (% of total employment) (modeled ILO estimate)                         151
# Employment in agriculture, female (% of female employment) (modeled ILO estimate)                151
# Employment in industry, female (% of female employment) (modeled ILO estimate)                   151
# Employment in services (% of total employment) (modeled ILO estimate)                            151
# Employment in services, female (% of female employment) (modeled ILO estimate)                   151
# Employment to population ratio, 15+, male (%) (modeled ILO estimate)                             151
# Fertility rate, total (births per woman)                                                         151
# GDP per capita (current US$)                                                                     151
# Incidence of tuberculosis (per 100,000 people)                                                   151
# Individuals using the Internet (% of population)                                                 151
# Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate)      151
# Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)    151
# Life expectancy at birth, female (years)                                                         151
# Life expectancy at birth, male (years)                                                           151
# Life expectancy at birth, total (years)                                                          151
# Merchandise exports by the reporting economy (current US$)                                       151
# Merchandise exports to high-income economies (% of total merchandise exports)                    151
# Net migration                                                                                    151
# Rural population (% of total population)                                                         151
# Secure Internet servers (per 1 million people)                                                   151
# Self-employed, female (% of female employment) (modeled ILO estimate)                            151
# Self-employed, total (% of total employment) (modeled ILO estimate)                              151
# Sex ratio at birth (male births per female births)                                               151
# Survival to age 65, female (% of cohort)                                                         151
# Survival to age 65, male (% of cohort)                                                           151
# Unemployment, female (% of female labor force) (modeled ILO estimate)                            151
# Unemployment, male (% of male labor force) (modeled ILO estimate)                                151
# Unemployment, total (% of total labor force) (modeled ILO estimate)                              151
# Urban population (% of total population)                                                         151
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
# Scale your data
# Import dependencies
from sklearn.preprocessing import LabelEncoder, MinMaxScaler,StandardScaler
from tensorflow.keras.utils import to_categorical

# scale the data
X_scaler =  MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train.values.ravel())
encoded_y_train = label_encoder.transform(y_train.values.ravel())
encoded_y_test = label_encoder.transform(y_test.values.ravel())

print(encoded_y_train)
print(encoded_y_test)
# Out:
# [1 1 3 3 1 3 2 3 0 2 3 0 1 0 1 2 4 1 2 1 0 0 0 4 0 3 1 4 3 3 0 0 1 2 4 2 3
#  0 0 0 3 3 0 3 3 3 3 0 0 0 1 4 1 2 0 2 2 4 1 4 2 0 2 1 3 4 0 1 3 1 1 2 1 2
#  3 1 0 3 2 1 3 3 4 4 0 2 2 0 1 3 3 4 0 1 4 1 4 3 4 2 0 1 2 1 3 3 4 3 2 1 4
#  3 4]
# [2 4 1 2 1 4 4 3 4 2 3 1 0 2 1 2 2 2 4 0 0 4 4 1 2 1 0 2 3 2 4 3 3 0 2 1 1
#  4]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# Fitting our model with all of our features in X
model.fit(X_train_scaled, encoded_y_train)

score = model.score(X_train_scaled, encoded_y_train)
print(f"R2 Score: {score}")
# Out:
# R2 Score: 0.6612353756976739

# %%
predictions = model.predict(X_test_scaled)
# Plot Residuals
plt.scatter(predictions, predictions - encoded_y_test)
plt.hlines(y=0, xmin=predictions.min(), xmax=predictions.max())
plt.show()

# %%
print(f"Training Data Score: {model.score(X_train_scaled, encoded_y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled, encoded_y_test)}")
# Out:
# Training Data Score: 0.6612353756976739
# Testing Data Score: -0.10139289998677192
