# %%
from sklearn import tree
import pandas as pd
import os

# %%
# SQL Alchemy
from sqlalchemy import create_engine

# %%
# Create Engine for employee db
engine = create_engine('postgres://sxwlsbsllohawb:4723d0dab89d2da6bf1aae12930fd6865874a185e4e4dca60e5af580ccd1a185@ec2-52-200-48-116.compute-1.amazonaws.com:5432/d7shhrp5hdjs4d')
#engine = create_engine('postgresql://swain:db@localhost:5432/world_happiness')
connection = engine.connect()

# %%
indicators_df = pd.read_sql("select * from happiness_indicators_final", connection)
                              
indicators_df.head()
# Out:
#    countryname                                      indicatorname      value  \
# 0  Afghanistan               Birth rate, crude (per 1,000 people)  33.211000
# 1  Afghanistan  Employment in agriculture (% of total employme...  43.988998
# 2  Afghanistan  Employment in agriculture, female (% of female...  66.218002
# 3  Afghanistan  Employment in industry, female (% of female em...  24.278999
# 4  Afghanistan  Employment in services, female (% of female em...   9.504000
#
#   target_groups
# 0      Very Sad
# 1      Very Sad
# 2      Very Sad
# 3      Very Sad
# 4      Very Sad

# %%
pivot_df = indicators_df.pivot(index='countryname', columns='indicatorname', values='value')

# %%
pivot_df.head()
# Out:
# indicatorname  Birth rate, crude (per 1,000 people)  \
# countryname
# Afghanistan                                  33.211
# Albania                                      11.934
# Algeria                                      24.846
# Angola                                       41.281
# Argentina                                    17.205
#
# indicatorname  Employment in agriculture (% of total employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            43.988998
# Albania                                                38.203999
# Algeria                                                10.160000
# Angola                                                 50.557999
# Argentina                                               0.059000
#
# indicatorname  Employment in agriculture, female (% of female employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            66.218002
# Albania                                                42.542000
# Algeria                                                 3.841000
# Angola                                                 56.988998
# Argentina                                               0.015000
#
# indicatorname  Employment in industry, female (% of female employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            24.278999
# Albania                                                15.132000
# Algeria                                                24.360001
# Angola                                                  1.134000
# Argentina                                               9.166000
#
# indicatorname  Employment in services, female (% of female employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                             9.504000
# Albania                                                42.325001
# Algeria                                                71.799004
# Angola                                                 41.877998
# Argentina                                              90.819000
#
# indicatorname  Employment to population ratio, 15+, male (%) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            66.950996
# Albania                                                55.379002
# Algeria                                                60.862000
# Angola                                                 73.719002
# Argentina                                              67.257004
#
# indicatorname  Fixed telephone subscriptions (per 100 people)  \
# countryname
# Afghanistan                                          0.327222
# Albania                                              8.554284
# Algeria                                              9.908341
# Angola                                               0.540199
# Argentina                                           22.177975
#
# indicatorname  GDP per capita (current US$)  GDP per capita growth (annual %)  \
# countryname
# Afghanistan                      556.302002                          0.082079
# Albania                         4531.020806                          3.897711
# Algeria                         4044.276600                         -0.750500
# Angola                          4095.812942                         -3.409903
# Argentina                      14591.863380                          1.609282
#
# indicatorname  Incidence of tuberculosis (per 100,000 people)  ...  \
# countryname                                                    ...
# Afghanistan                                             189.0  ...
# Albania                                                  20.0  ...
# Algeria                                                  70.0  ...
# Angola                                                  359.0  ...
# Argentina                                                27.0  ...
#
# indicatorname  Lifetime risk of maternal death (%)  \
# countryname
# Afghanistan                               3.063593
# Albania                                   0.026286
# Algeria                                   0.368716
# Angola                                    1.451251
# Argentina                                 0.091957
#
# indicatorname  Mobile cellular subscriptions (per 100 people)  \
# countryname
# Afghanistan                                         65.929134
# Albania                                            125.710352
# Algeria                                            110.767246
# Angola                                              44.686107
# Argentina                                          140.877124
#
# indicatorname  Mortality rate, infant (per 1,000 live births)  Net migration  \
# countryname
# Afghanistan                                              49.5      -314602.0
# Albania                                                   8.0       -69998.0
# Algeria                                                  20.6       -50002.0
# Angola                                                   53.4        32066.0
# Argentina                                                 9.3        24000.0
#
# indicatorname  Rural population (% of total population)  \
# countryname
# Afghanistan                                      74.750
# Albania                                          40.617
# Algeria                                          27.948
# Angola                                           35.161
# Argentina                                         8.251
#
# indicatorname  Secure Internet servers (per 1 million people)  \
# countryname
# Afghanistan                                         43.447835
# Albania                                            443.020376
# Algeria                                             63.325702
# Angola                                              10.799300
# Argentina                                         1628.591391
#
# indicatorname  Survival to age 65, female (% of cohort)  \
# countryname
# Afghanistan                                   67.574376
# Albania                                       91.145395
# Algeria                                       85.829405
# Angola                                        63.665746
# Argentina                                     86.900558
#
# indicatorname  Survival to age 65, male (% of cohort)  \
# countryname
# Afghanistan                                 60.950303
# Albania                                     84.702788
# Algeria                                     81.889538
# Angola                                      50.634695
# Argentina                                   76.722114
#
# indicatorname  Tuberculosis case detection rate (%, all forms)  \
# countryname
# Afghanistan                                               68.0
# Albania                                                   87.0
# Algeria                                                   80.0
# Angola                                                    51.0
# Argentina                                                 87.0
#
# indicatorname  Urban population (% of total population)
# countryname
# Afghanistan                                      25.250
# Albania                                          59.383
# Algeria                                          72.052
# Angola                                           64.839
# Argentina                                        91.749
#
# [5 rows x 25 columns]

# %%
pivot_df=pivot_df.dropna(how='any')

# %%
pivot_df.count()
# Out:
# indicatorname
# Birth rate, crude (per 1,000 people)                                                             149
# Employment in agriculture (% of total employment) (modeled ILO estimate)                         149
# Employment in agriculture, female (% of female employment) (modeled ILO estimate)                149
# Employment in industry, female (% of female employment) (modeled ILO estimate)                   149
# Employment in services, female (% of female employment) (modeled ILO estimate)                   149
# Employment to population ratio, 15+, male (%) (modeled ILO estimate)                             149
# Fixed telephone subscriptions (per 100 people)                                                   149
# GDP per capita (current US$)                                                                     149
# GDP per capita growth (annual %)                                                                 149
# Incidence of tuberculosis (per 100,000 people)                                                   149
# Individuals using the Internet (% of population)                                                 149
# Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)    149
# Life expectancy at birth, female (years)                                                         149
# Life expectancy at birth, male (years)                                                           149
# Life expectancy at birth, total (years)                                                          149
# Lifetime risk of maternal death (%)                                                              149
# Mobile cellular subscriptions (per 100 people)                                                   149
# Mortality rate, infant (per 1,000 live births)                                                   149
# Net migration                                                                                    149
# Rural population (% of total population)                                                         149
# Secure Internet servers (per 1 million people)                                                   149
# Survival to age 65, female (% of cohort)                                                         149
# Survival to age 65, male (% of cohort)                                                           149
# Tuberculosis case detection rate (%, all forms)                                                  149
# Urban population (% of total population)                                                         149
# dtype: int64

# %%
target_groups_df = pd.read_sql("SELECT distinct countryname,target_groups  from happiness_indicators_final", connection)
                              
target_groups_df.head()
# Out:
#    countryname     target_groups
# 0     Thailand   Extremely Happy
# 1         Iraq    Moderately Sad
# 2       Angola          Very Sad
# 3      Ireland   Extremely Happy
# 4  El Salvador  Moderately Happy

# %%
merged_df = pd.merge(pivot_df, target_groups_df 
                   ,left_on="countryname"
                   ,right_on = "countryname"
                   ,how="inner")

# %%
merged_df.head()
# Out:
#    countryname  Birth rate, crude (per 1,000 people)  \
# 0  Afghanistan                                33.211
# 1      Albania                                11.934
# 2      Algeria                                24.846
# 3       Angola                                41.281
# 4    Argentina                                17.205
#
#    Employment in agriculture (% of total employment) (modeled ILO estimate)  \
# 0                                          43.988998
# 1                                          38.203999
# 2                                          10.160000
# 3                                          50.557999
# 4                                           0.059000
#
#    Employment in agriculture, female (% of female employment) (modeled ILO estimate)  \
# 0                                          66.218002
# 1                                          42.542000
# 2                                           3.841000
# 3                                          56.988998
# 4                                           0.015000
#
#    Employment in industry, female (% of female employment) (modeled ILO estimate)  \
# 0                                          24.278999
# 1                                          15.132000
# 2                                          24.360001
# 3                                           1.134000
# 4                                           9.166000
#
#    Employment in services, female (% of female employment) (modeled ILO estimate)  \
# 0                                           9.504000
# 1                                          42.325001
# 2                                          71.799004
# 3                                          41.877998
# 4                                          90.819000
#
#    Employment to population ratio, 15+, male (%) (modeled ILO estimate)  \
# 0                                          66.950996
# 1                                          55.379002
# 2                                          60.862000
# 3                                          73.719002
# 4                                          67.257004
#
#    Fixed telephone subscriptions (per 100 people)  \
# 0                                        0.327222
# 1                                        8.554284
# 2                                        9.908341
# 3                                        0.540199
# 4                                       22.177975
#
#    GDP per capita (current US$)  GDP per capita growth (annual %)  ...  \
# 0                    556.302002                          0.082079  ...
# 1                   4531.020806                          3.897711  ...
# 2                   4044.276600                         -0.750500  ...
# 3                   4095.812942                         -3.409903  ...
# 4                  14591.863380                          1.609282  ...
#
#    Mobile cellular subscriptions (per 100 people)  \
# 0                                       65.929134
# 1                                      125.710352
# 2                                      110.767246
# 3                                       44.686107
# 4                                      140.877124
#
#    Mortality rate, infant (per 1,000 live births)  Net migration  \
# 0                                            49.5      -314602.0
# 1                                             8.0       -69998.0
# 2                                            20.6       -50002.0
# 3                                            53.4        32066.0
# 4                                             9.3        24000.0
#
#    Rural population (% of total population)  \
# 0                                    74.750
# 1                                    40.617
# 2                                    27.948
# 3                                    35.161
# 4                                     8.251
#
#    Secure Internet servers (per 1 million people)  \
# 0                                       43.447835
# 1                                      443.020376
# 2                                       63.325702
# 3                                       10.799300
# 4                                     1628.591391
#
#    Survival to age 65, female (% of cohort)  \
# 0                                 67.574376
# 1                                 91.145395
# 2                                 85.829405
# 3                                 63.665746
# 4                                 86.900558
#
#    Survival to age 65, male (% of cohort)  \
# 0                               60.950303
# 1                               84.702788
# 2                               81.889538
# 3                               50.634695
# 4                               76.722114
#
#    Tuberculosis case detection rate (%, all forms)  \
# 0                                             68.0
# 1                                             87.0
# 2                                             80.0
# 3                                             51.0
# 4                                             87.0
#
#    Urban population (% of total population)     target_groups
# 0                                    25.250          Very Sad
# 1                                    59.383    Moderately Sad
# 2                                    72.052  Moderately Happy
# 3                                    64.839          Very Sad
# 4                                    91.749   Extremely Happy
#
# [5 rows x 27 columns]

# %%
target = merged_df["target_groups"]
target.head()
# Out:
# 0            Very Sad
# 1      Moderately Sad
# 2    Moderately Happy
# 3            Very Sad
# 4     Extremely Happy
# Name: target_groups, dtype: object

# %%
target_names = pd.read_sql("SELECT distinct target_groups  from happiness_indicators_final", connection)
target_names
# Out:
#       target_groups
# 0   Extremely Happy
# 1         Apathetic
# 2  Moderately Happy
# 3    Moderately Sad
# 4          Very Sad

# %%
data = merged_df.drop(["target_groups","countryname"], axis=1)

# %%
feature_names = data.columns
data.head()
# Out:
#    Birth rate, crude (per 1,000 people)  \
# 0                                33.211
# 1                                11.934
# 2                                24.846
# 3                                41.281
# 4                                17.205
#
#    Employment in agriculture (% of total employment) (modeled ILO estimate)  \
# 0                                          43.988998
# 1                                          38.203999
# 2                                          10.160000
# 3                                          50.557999
# 4                                           0.059000
#
#    Employment in agriculture, female (% of female employment) (modeled ILO estimate)  \
# 0                                          66.218002
# 1                                          42.542000
# 2                                           3.841000
# 3                                          56.988998
# 4                                           0.015000
#
#    Employment in industry, female (% of female employment) (modeled ILO estimate)  \
# 0                                          24.278999
# 1                                          15.132000
# 2                                          24.360001
# 3                                           1.134000
# 4                                           9.166000
#
#    Employment in services, female (% of female employment) (modeled ILO estimate)  \
# 0                                           9.504000
# 1                                          42.325001
# 2                                          71.799004
# 3                                          41.877998
# 4                                          90.819000
#
#    Employment to population ratio, 15+, male (%) (modeled ILO estimate)  \
# 0                                          66.950996
# 1                                          55.379002
# 2                                          60.862000
# 3                                          73.719002
# 4                                          67.257004
#
#    Fixed telephone subscriptions (per 100 people)  \
# 0                                        0.327222
# 1                                        8.554284
# 2                                        9.908341
# 3                                        0.540199
# 4                                       22.177975
#
#    GDP per capita (current US$)  GDP per capita growth (annual %)  \
# 0                    556.302002                          0.082079
# 1                   4531.020806                          3.897711
# 2                   4044.276600                         -0.750500
# 3                   4095.812942                         -3.409903
# 4                  14591.863380                          1.609282
#
#    Incidence of tuberculosis (per 100,000 people)  ...  \
# 0                                           189.0  ...
# 1                                            20.0  ...
# 2                                            70.0  ...
# 3                                           359.0  ...
# 4                                            27.0  ...
#
#    Lifetime risk of maternal death (%)  \
# 0                             3.063593
# 1                             0.026286
# 2                             0.368716
# 3                             1.451251
# 4                             0.091957
#
#    Mobile cellular subscriptions (per 100 people)  \
# 0                                       65.929134
# 1                                      125.710352
# 2                                      110.767246
# 3                                       44.686107
# 4                                      140.877124
#
#    Mortality rate, infant (per 1,000 live births)  Net migration  \
# 0                                            49.5      -314602.0
# 1                                             8.0       -69998.0
# 2                                            20.6       -50002.0
# 3                                            53.4        32066.0
# 4                                             9.3        24000.0
#
#    Rural population (% of total population)  \
# 0                                    74.750
# 1                                    40.617
# 2                                    27.948
# 3                                    35.161
# 4                                     8.251
#
#    Secure Internet servers (per 1 million people)  \
# 0                                       43.447835
# 1                                      443.020376
# 2                                       63.325702
# 3                                       10.799300
# 4                                     1628.591391
#
#    Survival to age 65, female (% of cohort)  \
# 0                                 67.574376
# 1                                 91.145395
# 2                                 85.829405
# 3                                 63.665746
# 4                                 86.900558
#
#    Survival to age 65, male (% of cohort)  \
# 0                               60.950303
# 1                               84.702788
# 2                               81.889538
# 3                               50.634695
# 4                               76.722114
#
#    Tuberculosis case detection rate (%, all forms)  \
# 0                                             68.0
# 1                                             87.0
# 2                                             80.0
# 3                                             51.0
# 4                                             87.0
#
#    Urban population (% of total population)
# 0                                    25.250
# 1                                    59.383
# 2                                    72.052
# 3                                    64.839
# 4                                    91.749
#
# [5 rows x 25 columns]

# %%
data.count()
# Out:
# Birth rate, crude (per 1,000 people)                                                             149
# Employment in agriculture (% of total employment) (modeled ILO estimate)                         149
# Employment in agriculture, female (% of female employment) (modeled ILO estimate)                149
# Employment in industry, female (% of female employment) (modeled ILO estimate)                   149
# Employment in services, female (% of female employment) (modeled ILO estimate)                   149
# Employment to population ratio, 15+, male (%) (modeled ILO estimate)                             149
# Fixed telephone subscriptions (per 100 people)                                                   149
# GDP per capita (current US$)                                                                     149
# GDP per capita growth (annual %)                                                                 149
# Incidence of tuberculosis (per 100,000 people)                                                   149
# Individuals using the Internet (% of population)                                                 149
# Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)    149
# Life expectancy at birth, female (years)                                                         149
# Life expectancy at birth, male (years)                                                           149
# Life expectancy at birth, total (years)                                                          149
# Lifetime risk of maternal death (%)                                                              149
# Mobile cellular subscriptions (per 100 people)                                                   149
# Mortality rate, infant (per 1,000 live births)                                                   149
# Net migration                                                                                    149
# Rural population (% of total population)                                                         149
# Secure Internet servers (per 1 million people)                                                   149
# Survival to age 65, female (% of cohort)                                                         149
# Survival to age 65, male (% of cohort)                                                           149
# Tuberculosis case detection rate (%, all forms)                                                  149
# Urban population (% of total population)                                                         149
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.5

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.5526315789473685

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.07135612356569059, 'Life expectancy at birth, total (years)'),
#  (0.07004103789976772, 'Life expectancy at birth, female (years)'),
#  (0.061201265059350696, 'Life expectancy at birth, male (years)'),
#  (0.061194821081976665, 'GDP per capita (current US$)'),
#  (0.05415421656267197, 'Survival to age 65, female (% of cohort)'),
#  (0.04987817811995535, 'Urban population (% of total population)'),
#  (0.048115833032323696,
#   'Employment in services, female (% of female employment) (modeled ILO estimate)'),
#  (0.04781767697572263, 'Rural population (% of total population)'),
#  (0.042052577789432076,
#   'Employment in agriculture, female (% of female employment) (modeled ILO estimate)'),
#  (0.039816179450738176, 'Mobile cellular subscriptions (per 100 people)'),
#  (0.03964455244250334, 'Lifetime risk of maternal death (%)'),
#  (0.037724765859866366, 'Survival to age 65, male (% of cohort)'),
#  (0.03599785776262642,
#   'Employment to population ratio, 15+, male (%) (modeled ILO estimate)'),
#  (0.0342257889024511, 'Mortality rate, infant (per 1,000 live births)'),
#  (0.03204134078740083,
#   'Employment in industry, female (% of female employment) (modeled ILO estimate)'),
#  (0.031778315611362296, 'Net migration'),
#  (0.03175572247067767,
#   'Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)'),
#  (0.031229665824617888, 'Fixed telephone subscriptions (per 100 people)'),
#  (0.03056130960629772, 'Incidence of tuberculosis (per 100,000 people)'),
#  (0.029690890083336106,
#   'Employment in agriculture (% of total employment) (modeled ILO estimate)'),
#  (0.02901097505262107, 'Individuals using the Internet (% of population)'),
#  (0.025193128381126258, 'Birth rate, crude (per 1,000 people)'),
#  (0.024290423522596024, 'Secure Internet servers (per 1 million people)'),
#  (0.022423205338994986, 'GDP per capita growth (annual %)'),
#  (0.018804148815892374, 'Tuberculosis case detection rate (%, all forms)')]

# %%
import matplotlib.pyplot as plt
feats = {} # a dict to hold feature_name: feature_importance
for feature, importance in zip(data.columns, rf.feature_importances_):
    feats[feature] = importance #add the name/value pair 

importances = pd.DataFrame.from_dict(feats, orient='index').rename(columns={0: 'Gini-importance'})
importances.sort_values(by='Gini-importance').plot(kind='bar')#, rot=45)
# Save the figure
plt.savefig("../rf-graph.png")
plt.show()

# %%
#append data to Postgres existing table
importances.to_sql('forest_importance', engine,if_exists='replace')

# %%
model_score = rf.score(X_test, y_test)
model_score_df = pd.Series(model_score)

# %%
#append data to Postgres existing table
model_score_df.to_sql('model_score', engine,if_exists='replace')

# %%
from graphviz import Source
from sklearn import tree
Source(tree.export_graphviz(clf, out_file=None, feature_names=data.columns))

# %%
#import pickle
#with open('rf-model.sav', 'wb') as f:
    #pickle.dump(rf, f)

# %%
# in your prediction file   
#with open('rf-model.sav', 'rb') as f:
    #rf = pickle.load(f)
#preds = rf.predict(data)
