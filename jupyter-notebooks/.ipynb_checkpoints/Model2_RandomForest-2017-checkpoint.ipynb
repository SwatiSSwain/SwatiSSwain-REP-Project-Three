# %%
from sklearn import tree
import pandas as pd
import os

# %%
# SQL Alchemy
from sqlalchemy import create_engine

# %%
# Create Engine for employee db
#engine = create_engine('postgres://sxwlsbsllohawb:4723d0dab89d2da6bf1aae12930fd6865874a185e4e4dca60e5af580ccd1a185@ec2-52-200-48-116.compute-1.amazonaws.com:5432/d7shhrp5hdjs4d')
engine = create_engine('postgresql://swain:db@localhost:5432/world_happiness')
connection = engine.connect()

# %%
indicators_df = pd.read_sql("SELECT * from table4_2017", connection)
                              
indicators_df.head()
# Out:
#    countryname                                      indicatorname  \
# 0  Afghanistan            Access to electricity (% of population)
# 1  Afghanistan   Adjusted savings: energy depletion (current US$)
# 2  Afghanistan  Adjusted savings: mineral depletion (current US$)
# 3  Afghanistan  Adolescent fertility rate (births per 1,000 wo...
# 4  Afghanistan  Age dependency ratio (% of working-age populat...
#
#       year_2017 target_groups
# 0  9.770000e+01      Very Sad
# 1  2.110297e+07      Very Sad
# 2  9.537887e+05      Very Sad
# 3  6.895700e+01      Very Sad
# 4  8.600075e+01      Very Sad

# %%
pivot_df = indicators_df.pivot(index='countryname', columns='indicatorname', values='year_2017')

# %%
pivot_df.head()
# Out:
# indicatorname  Access to electricity (% of population)  \
# countryname
# Afghanistan                                  97.700000
# Albania                                     100.000000
# Algeria                                     100.000000
# Angola                                       41.962894
# Argentina                                   100.000000
#
# indicatorname  Adjusted savings: energy depletion (current US$)  \
# countryname
# Afghanistan                                        2.110297e+07
# Albania                                            1.196189e+08
# Algeria                                            1.517693e+10
# Angola                                             1.497083e+10
# Argentina                                          4.903240e+09
#
# indicatorname  Adjusted savings: mineral depletion (current US$)  \
# countryname
# Afghanistan                                         9.537887e+05
# Albania                                             2.261126e+06
# Algeria                                             8.871101e+06
# Angola                                              0.000000e+00
# Argentina                                           1.431438e+09
#
# indicatorname  Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# countryname
# Afghanistan                                               68.957
# Albania                                                   19.642
# Algeria                                                   10.071
# Angola                                                   150.526
# Argentina                                                 62.782
#
# indicatorname  Age dependency ratio (% of working-age population)  \
# countryname
# Afghanistan                                            86.000753
# Albania                                                45.682097
# Algeria                                                55.804001
# Angola                                                 96.820228
# Argentina                                              56.046355
#
# indicatorname  Birth rate, crude (per 1,000 people)  \
# countryname
# Afghanistan                                  33.211
# Albania                                      11.934
# Algeria                                      24.846
# Angola                                       41.281
# Argentina                                    17.205
#
# indicatorname  Contributing family workers, female (% of female employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            68.609001
# Albania                                                38.580002
# Algeria                                                 2.419000
# Angola                                                 10.554000
# Argentina                                               0.977000
#
# indicatorname  Contributing family workers, male (% of male employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            12.401000
# Albania                                                21.372999
# Algeria                                                 1.834000
# Angola                                                  7.986000
# Argentina                                               0.307000
#
# indicatorname  Contributing family workers, total (% of total employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                               23.763
# Albania                                                   28.600
# Algeria                                                    1.927
# Angola                                                     9.269
# Argentina                                                  0.587
#
# indicatorname  Death rate, crude (per 1,000 people)  ...  \
# countryname                                          ...
# Afghanistan                                   6.575  ...
# Albania                                       7.714  ...
# Algeria                                       4.717  ...
# Angola                                        8.432  ...
# Argentina                                     7.616  ...
#
# indicatorname  Unemployment, female (% of female labor force) (modeled ILO estimate)  \
# countryname
# Afghanistan                                               14.090
# Albania                                                   12.563
# Algeria                                                   21.114
# Angola                                                     7.467
# Argentina                                                  9.464
#
# indicatorname  Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# countryname
# Afghanistan                                               10.416
# Albania                                                   14.590
# Algeria                                                   10.021
# Angola                                                     6.769
# Argentina                                                  7.527
#
# indicatorname  Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# countryname
# Afghanistan                                               11.184
# Albania                                                   13.750
# Algeria                                                   11.996
# Angola                                                     7.119
# Argentina                                                  8.347
#
# indicatorname  Urban population  Urban population (% of total population)  \
# countryname
# Afghanistan           9164841.0                                    25.250
# Albania               1706345.0                                    59.383
# Algeria              29821745.0                                    72.052
# Angola               19332881.0                                    64.839
# Argentina            40410674.0                                    91.749
#
# indicatorname  Urban population growth (annual %)  \
# countryname
# Afghanistan                              3.463407
# Albania                                  1.541285
# Algeria                                  2.871374
# Angola                                   4.391957
# Argentina                                1.170196
#
# indicatorname  Wage and salaried workers, female (% of female employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                             7.551000
# Albania                                                44.298000
# Algeria                                                74.598999
# Angola                                                 17.445000
# Argentina                                              78.545998
#
# indicatorname  Wage and salaried workers, male (% of male employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            20.083000
# Albania                                                41.727001
# Algeria                                                67.067001
# Angola                                                 41.287998
# Argentina                                              71.865997
#
# indicatorname  Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            17.549999
# Albania                                                42.806999
# Algeria                                                68.268997
# Angola                                                 29.374001
# Argentina                                              74.660004
#
# indicatorname  Women Business and the Law Index Score (scale 1-100)
# countryname
# Afghanistan                                                 38.1
# Albania                                                     91.3
# Algeria                                                     57.5
# Angola                                                      73.1
# Argentina                                                   73.1
#
# [5 rows x 86 columns]

# %%
pivot_df=pivot_df.dropna(how='any')

# %%
pivot_df.count()
# Out:
# indicatorname
# Access to electricity (% of population)                                              151
# Adjusted savings: energy depletion (current US$)                                     151
# Adjusted savings: mineral depletion (current US$)                                    151
# Adolescent fertility rate (births per 1,000 women ages 15-19)                        151
# Age dependency ratio (% of working-age population)                                   151
#                                                                                     ...
# Urban population growth (annual %)                                                   151
# Wage and salaried workers, female (% of female employment) (modeled ILO estimate)    151
# Wage and salaried workers, male (% of male employment) (modeled ILO estimate)        151
# Wage and salaried workers, total (% of total employment) (modeled ILO estimate)      151
# Women Business and the Law Index Score (scale 1-100)                                 151
# Length: 86, dtype: int64

# %%
target_groups_df = pd.read_sql("SELECT distinct countryname,target_groups  from table4_2017", connection)
                              
target_groups_df.head()
# Out:
#   countryname    target_groups
# 0      Angola         Very Sad
# 1     Ireland  Extremely Happy
# 2      Malawi         Very Sad
# 3      Rwanda         Very Sad
# 4     Denmark  Extremely Happy

# %%
merged_df = pd.merge(pivot_df, target_groups_df 
                   ,left_on="countryname"
                   ,right_on = "countryname"
                   ,how="inner")

# %%
merged_df.head()
# Out:
#    countryname  Access to electricity (% of population)  \
# 0  Afghanistan                                97.700000
# 1      Albania                               100.000000
# 2      Algeria                               100.000000
# 3       Angola                                41.962894
# 4    Argentina                               100.000000
#
#    Adjusted savings: energy depletion (current US$)  \
# 0                                      2.110297e+07
# 1                                      1.196189e+08
# 2                                      1.517693e+10
# 3                                      1.497083e+10
# 4                                      4.903240e+09
#
#    Adjusted savings: mineral depletion (current US$)  \
# 0                                       9.537887e+05
# 1                                       2.261126e+06
# 2                                       8.871101e+06
# 3                                       0.000000e+00
# 4                                       1.431438e+09
#
#    Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                             68.957
# 1                                             19.642
# 2                                             10.071
# 3                                            150.526
# 4                                             62.782
#
#    Age dependency ratio (% of working-age population)  \
# 0                                          86.000753
# 1                                          45.682097
# 2                                          55.804001
# 3                                          96.820228
# 4                                          56.046355
#
#    Birth rate, crude (per 1,000 people)  \
# 0                                33.211
# 1                                11.934
# 2                                24.846
# 3                                41.281
# 4                                17.205
#
#    Contributing family workers, female (% of female employment) (modeled ILO estimate)  \
# 0                                          68.609001
# 1                                          38.580002
# 2                                           2.419000
# 3                                          10.554000
# 4                                           0.977000
#
#    Contributing family workers, male (% of male employment) (modeled ILO estimate)  \
# 0                                          12.401000
# 1                                          21.372999
# 2                                           1.834000
# 3                                           7.986000
# 4                                           0.307000
#
#    Contributing family workers, total (% of total employment) (modeled ILO estimate)  \
# 0                                             23.763
# 1                                             28.600
# 2                                              1.927
# 3                                              9.269
# 4                                              0.587
#
#    ...  Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# 0  ...                                             10.416
# 1  ...                                             14.590
# 2  ...                                             10.021
# 3  ...                                              6.769
# 4  ...                                              7.527
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                             11.184
# 1                                             13.750
# 2                                             11.996
# 3                                              7.119
# 4                                              8.347
#
#    Urban population  Urban population (% of total population)  \
# 0         9164841.0                                    25.250
# 1         1706345.0                                    59.383
# 2        29821745.0                                    72.052
# 3        19332881.0                                    64.839
# 4        40410674.0                                    91.749
#
#    Urban population growth (annual %)  \
# 0                            3.463407
# 1                            1.541285
# 2                            2.871374
# 3                            4.391957
# 4                            1.170196
#
#    Wage and salaried workers, female (% of female employment) (modeled ILO estimate)  \
# 0                                           7.551000
# 1                                          44.298000
# 2                                          74.598999
# 3                                          17.445000
# 4                                          78.545998
#
#    Wage and salaried workers, male (% of male employment) (modeled ILO estimate)  \
# 0                                          20.083000
# 1                                          41.727001
# 2                                          67.067001
# 3                                          41.287998
# 4                                          71.865997
#
#    Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  \
# 0                                          17.549999
# 1                                          42.806999
# 2                                          68.268997
# 3                                          29.374001
# 4                                          74.660004
#
#    Women Business and the Law Index Score (scale 1-100)     target_groups
# 0                                               38.1             Very Sad
# 1                                               91.3       Moderately Sad
# 2                                               57.5     Moderately Happy
# 3                                               73.1             Very Sad
# 4                                               73.1      Extremely Happy
#
# [5 rows x 88 columns]

# %%
target = merged_df["target_groups"]
target.head()
# Out:
# 0            Very Sad
# 1      Moderately Sad
# 2    Moderately Happy
# 3            Very Sad
# 4     Extremely Happy
# Name: target_groups, dtype: object

# %%
target_names = pd.read_sql("SELECT distinct target_groups  from table4_2017", connection)
target_names
# Out:
#       target_groups
# 0   Extremely Happy
# 1         Apathetic
# 2  Moderately Happy
# 3    Moderately Sad
# 4          Very Sad

# %%
data = merged_df.drop(["target_groups","countryname"], axis=1)

# %%
feature_names = data.columns
data.head()
# Out:
#    Access to electricity (% of population)  \
# 0                                97.700000
# 1                               100.000000
# 2                               100.000000
# 3                                41.962894
# 4                               100.000000
#
#    Adjusted savings: energy depletion (current US$)  \
# 0                                      2.110297e+07
# 1                                      1.196189e+08
# 2                                      1.517693e+10
# 3                                      1.497083e+10
# 4                                      4.903240e+09
#
#    Adjusted savings: mineral depletion (current US$)  \
# 0                                       9.537887e+05
# 1                                       2.261126e+06
# 2                                       8.871101e+06
# 3                                       0.000000e+00
# 4                                       1.431438e+09
#
#    Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                             68.957
# 1                                             19.642
# 2                                             10.071
# 3                                            150.526
# 4                                             62.782
#
#    Age dependency ratio (% of working-age population)  \
# 0                                          86.000753
# 1                                          45.682097
# 2                                          55.804001
# 3                                          96.820228
# 4                                          56.046355
#
#    Birth rate, crude (per 1,000 people)  \
# 0                                33.211
# 1                                11.934
# 2                                24.846
# 3                                41.281
# 4                                17.205
#
#    Contributing family workers, female (% of female employment) (modeled ILO estimate)  \
# 0                                          68.609001
# 1                                          38.580002
# 2                                           2.419000
# 3                                          10.554000
# 4                                           0.977000
#
#    Contributing family workers, male (% of male employment) (modeled ILO estimate)  \
# 0                                          12.401000
# 1                                          21.372999
# 2                                           1.834000
# 3                                           7.986000
# 4                                           0.307000
#
#    Contributing family workers, total (% of total employment) (modeled ILO estimate)  \
# 0                                             23.763
# 1                                             28.600
# 2                                              1.927
# 3                                              9.269
# 4                                              0.587
#
#    Death rate, crude (per 1,000 people)  ...  \
# 0                                 6.575  ...
# 1                                 7.714  ...
# 2                                 4.717  ...
# 3                                 8.432  ...
# 4                                 7.616  ...
#
#    Unemployment, female (% of female labor force) (modeled ILO estimate)  \
# 0                                             14.090
# 1                                             12.563
# 2                                             21.114
# 3                                              7.467
# 4                                              9.464
#
#    Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# 0                                             10.416
# 1                                             14.590
# 2                                             10.021
# 3                                              6.769
# 4                                              7.527
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                             11.184
# 1                                             13.750
# 2                                             11.996
# 3                                              7.119
# 4                                              8.347
#
#    Urban population  Urban population (% of total population)  \
# 0         9164841.0                                    25.250
# 1         1706345.0                                    59.383
# 2        29821745.0                                    72.052
# 3        19332881.0                                    64.839
# 4        40410674.0                                    91.749
#
#    Urban population growth (annual %)  \
# 0                            3.463407
# 1                            1.541285
# 2                            2.871374
# 3                            4.391957
# 4                            1.170196
#
#    Wage and salaried workers, female (% of female employment) (modeled ILO estimate)  \
# 0                                           7.551000
# 1                                          44.298000
# 2                                          74.598999
# 3                                          17.445000
# 4                                          78.545998
#
#    Wage and salaried workers, male (% of male employment) (modeled ILO estimate)  \
# 0                                          20.083000
# 1                                          41.727001
# 2                                          67.067001
# 3                                          41.287998
# 4                                          71.865997
#
#    Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  \
# 0                                          17.549999
# 1                                          42.806999
# 2                                          68.268997
# 3                                          29.374001
# 4                                          74.660004
#
#    Women Business and the Law Index Score (scale 1-100)
# 0                                               38.1
# 1                                               91.3
# 2                                               57.5
# 3                                               73.1
# 4                                               73.1
#
# [5 rows x 86 columns]

# %%
data.count()
# Out:
# Access to electricity (% of population)                                              151
# Adjusted savings: energy depletion (current US$)                                     151
# Adjusted savings: mineral depletion (current US$)                                    151
# Adolescent fertility rate (births per 1,000 women ages 15-19)                        151
# Age dependency ratio (% of working-age population)                                   151
#                                                                                     ...
# Urban population growth (annual %)                                                   151
# Wage and salaried workers, female (% of female employment) (modeled ILO estimate)    151
# Wage and salaried workers, male (% of male employment) (modeled ILO estimate)        151
# Wage and salaried workers, total (% of total employment) (modeled ILO estimate)      151
# Women Business and the Law Index Score (scale 1-100)                                 151
# Length: 86, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.4473684210526316

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.5

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.0362072399305023, 'Life expectancy at birth, male (years)'),
#  (0.033731126997834086, 'GDP per capita (current US$)'),
#  (0.03200914163368508, 'Life expectancy at birth, female (years)'),
#  (0.029544303110225923,
#   'Employment in services, female (% of female employment) (modeled ILO estimate)'),
#  (0.027245367092720157,
#   'Employment in agriculture, female (% of female employment) (modeled ILO estimate)'),
#  (0.026751260882440942, 'Life expectancy at birth, total (years)'),
#  (0.024934679812845632, 'Survival to age 65, male (% of cohort)'),
#  (0.022706418310185928,
#   'Unemployment, total (% of total labor force) (modeled ILO estimate)'),
#  (0.022200298463216493, 'Birth rate, crude (per 1,000 people)'),
#  (0.019398696632223333, 'Secure Internet servers (per 1 million people)'),
#  (0.017511779291999242,
#   'Unemployment, male (% of male labor force) (modeled ILO estimate)'),
#  (0.017450079786002926, 'Net migration'),
#  (0.016979683877652335, 'Incidence of tuberculosis (per 100,000 people)'),
#  (0.015871775890011455, 'Rural population (% of total population)'),
#  (0.015830115253787917,
#   'Employers, total (% of total employment) (modeled ILO estimate)'),
#  (0.015230231009101012, 'Survival to age 65, female (% of cohort)'),
#  (0.014635833799939166,
#   'Employment in industry, female (% of female employment) (modeled ILO estimate)'),
#  (0.014290491615829985, 'Fertility rate, total (births per woman)'),
#  (0.014062245115613088,
#   'Employment in services (% of total employment) (modeled ILO estimate)'),
#  (0.013868888051544957,
#   'Employers, female (% of female employment) (modeled ILO estimate)'),
#  (0.013857760082654276, 'Individuals using the Internet (% of population)'),
#  (0.013718217107577493,
#   'Unemployment, female (% of female labor force) (modeled ILO estimate)'),
#  (0.013253318229323723, 'Urban population (% of total population)'),
#  (0.013165883171654007,
#   'Employment in agriculture (% of total employment) (modeled ILO estimate)'),
#  (0.01305847656409276,
#   'Self-employed, total (% of total employment) (modeled ILO estimate)'),
#  (0.012743882941665832, 'Age dependency ratio (% of working-age population)'),
#  (0.01253374268120682,
#   'Merchandise exports by the reporting economy (current US$)'),
#  (0.012274526405612997,
#   'Employment to population ratio, 15+, male (%) (modeled ILO estimate)'),
#  (0.012068915885196567, 'Sex ratio at birth (male births per female births)'),
#  (0.011653809276876372,
#   'Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)'),
#  (0.011012230570030122,
#   'Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate)'),
#  (0.010962286581735613,
#   'Self-employed, female (% of female employment) (modeled ILO estimate)'),
#  (0.010942023645216715,
#   'Merchandise exports to high-income economies (% of total merchandise exports)'),
#  (0.010941918188646786,
#   'Employers, male (% of male employment) (modeled ILO estimate)'),
#  (0.010908342439191563,
#   'Contributing family workers, female (% of female employment) (modeled ILO estimate)'),
#  (0.010746506576452512,
#   'Self-employed, male (% of male employment) (modeled ILO estimate)'),
#  (0.010642108364933464, 'Labor force, total'),
#  (0.010303596416541817,
#   'Employment in agriculture, male (% of male employment) (modeled ILO estimate)'),
#  (0.010302264266015935,
#   'Employment to population ratio, 15+, female (%) (modeled ILO estimate)'),
#  (0.01022587481352184,
#   'Employment in industry (% of total employment) (modeled ILO estimate)'),
#  (0.010143345565459913, 'Urban population growth (annual %)'),
#  (0.010051208974761455, 'Population growth (annual %)'),
#  (0.00985659345726508,
#   'Employment to population ratio, 15+, total (%) (modeled ILO estimate)'),
#  (0.009642434923280114, 'Population, female (% of total population)'),
#  (0.009529898382364172,
#   'Contributing family workers, male (% of male employment) (modeled ILO estimate)'),
#  (0.009424497255095768,
#   'Ease of doing business score (0 = lowest performance to 100 = best performance)'),
#  (0.009266469324492418,
#   'Wage and salaried workers, male (% of male employment) (modeled ILO estimate)'),
#  (0.009198923447802746, 'Tuberculosis case detection rate (%, all forms)'),
#  (0.009172323309104004, 'Inflation, GDP deflator (annual %)'),
#  (0.009167540087971975,
#   'Merchandise imports by the reporting economy (current US$)'),
#  (0.00916179096903354, 'Population, male'),
#  (0.009148701242660427, 'GDP growth (annual %)'),
#  (0.008888577124970898,
#   'Wage and salaried workers, total (% of total employment) (modeled ILO estimate)'),
#  (0.008722935085456606, 'Secure Internet servers'),
#  (0.008682062252511513, 'Population, male (% of total population)'),
#  (0.008474677840172938, 'GDP (current US$)'),
#  (0.008449986581083946, 'Population, female'),
#  (0.008365724858229378, 'Death rate, crude (per 1,000 people)'),
#  (0.008333103847486199,
#   'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'),
#  (0.008215124164076455,
#   'Employment in services, male (% of male employment) (modeled ILO estimate)'),
#  (0.007994932514616006,
#   'Wage and salaried workers, female (% of female employment) (modeled ILO estimate)'),
#  (0.00798860897862998,
#   'Merchandise imports from high-income economies (% of total merchandise imports)'),
#  (0.007827557157261437, 'Urban population'),
#  (0.0077271643077187115, 'Time required to start a business (days)'),
#  (0.007626281015266001, 'Population, total'),
#  (0.007481962160541176, 'Labor force, female (% of total labor force)'),
#  (0.007384215246318643,
#   'Women Business and the Law Index Score (scale 1-100)'),
#  (0.007308041576004391, 'Public credit registry coverage (% of adults)'),
#  (0.007306724134880106,
#   'Contributing family workers, total (% of total employment) (modeled ILO estimate)'),
#  (0.007112364535668312,
#   'Employment in industry, male (% of male employment) (modeled ILO estimate)'),
#  (0.006931144255627116, 'GDP per capita growth (annual %)'),
#  (0.0068049303091945205,
#   'Merchandise imports by the reporting economy, residual (% of total merchandise imports)'),
#  (0.006723440058384974, 'Mobile cellular subscriptions'),
#  (0.006470553442937399, 'Adjusted savings: mineral depletion (current US$)'),
#  (0.0062711668180761146,
#   'Ratio of female to male labor force participation rate (%) (modeled ILO estimate)'),
#  (0.005896824935604634,
#   'Merchandise exports by the reporting economy, residual (% of total merchandise exports)'),
#  (0.0056839072862086915,
#   'Adolescent fertility rate (births per 1,000 women ages 15-19)'),
#  (0.005622795794341904, 'Access to electricity (% of population)'),
#  (0.005475128124196626,
#   'Strength of legal rights index (0=weak to 12=strong)'),
#  (0.004431003620853531, 'Private credit bureau coverage (% of adults)'),
#  (0.004345774353511159, 'Depth of credit information index (0=low to 8=high)'),
#  (0.004273840357537467, 'Adjusted savings: energy depletion (current US$)'),
#  (0.002743900483466996, 'Secondary education, duration (years)'),
#  (0.002037238206330798, 'Lower secondary school starting age (years)'),
#  (0.0019441851374484716, 'Primary education, duration (years)'),
#  (0.0009150557305860743, 'Primary school starting age (years)')]
