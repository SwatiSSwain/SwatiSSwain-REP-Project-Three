# %%
from sklearn import tree
import pandas as pd
import os

# %%
# SQL Alchemy
from sqlalchemy import create_engine

# %%
# Create Engine for employee db
#engine = create_engine('postgres://sxwlsbsllohawb:4723d0dab89d2da6bf1aae12930fd6865874a185e4e4dca60e5af580ccd1a185@ec2-52-200-48-116.compute-1.amazonaws.com:5432/d7shhrp5hdjs4d')
engine = create_engine('postgresql://swain:db@localhost:5432/world_happiness')
connection = engine.connect()

# %%
indicators_df = pd.read_sql("SELECT * from table9_2017", connection)
                              
indicators_df.head()
# Out:
#    countryname                                      indicatorname  year_2017  \
# 0  Afghanistan               Birth rate, crude (per 1,000 people)  33.211000
# 1  Afghanistan  Employment in agriculture (% of total employme...  43.988998
# 2  Afghanistan  Employment in agriculture, female (% of female...  66.218002
# 3  Afghanistan  Employment in industry, female (% of female em...  24.278999
# 4  Afghanistan  Employment in services, female (% of female em...   9.504000
#
#   target_groups
# 0      Very Sad
# 1      Very Sad
# 2      Very Sad
# 3      Very Sad
# 4      Very Sad

# %%
pivot_df = indicators_df.pivot(index='countryname', columns='indicatorname', values='year_2017')

# %%
pivot_df.head()
# Out:
# indicatorname  Birth rate, crude (per 1,000 people)  \
# countryname
# Afghanistan                                  33.211
# Albania                                      11.934
# Algeria                                      24.846
# Angola                                       41.281
# Argentina                                    17.205
#
# indicatorname  Employment in agriculture (% of total employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            43.988998
# Albania                                                38.203999
# Algeria                                                10.160000
# Angola                                                 50.557999
# Argentina                                               0.059000
#
# indicatorname  Employment in agriculture, female (% of female employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            66.218002
# Albania                                                42.542000
# Algeria                                                 3.841000
# Angola                                                 56.988998
# Argentina                                               0.015000
#
# indicatorname  Employment in industry, female (% of female employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            24.278999
# Albania                                                15.132000
# Algeria                                                24.360001
# Angola                                                  1.134000
# Argentina                                               9.166000
#
# indicatorname  Employment in services, female (% of female employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                             9.504000
# Albania                                                42.325001
# Algeria                                                71.799004
# Angola                                                 41.877998
# Argentina                                              90.819000
#
# indicatorname  Employment to population ratio, 15+, male (%) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            66.950996
# Albania                                                55.379002
# Algeria                                                60.862000
# Angola                                                 73.719002
# Argentina                                              67.257004
#
# indicatorname  Fixed telephone subscriptions (per 100 people)  \
# countryname
# Afghanistan                                          0.327222
# Albania                                              8.554284
# Algeria                                              9.908341
# Angola                                               0.540199
# Argentina                                           22.177975
#
# indicatorname  GDP per capita (current US$)  GDP per capita growth (annual %)  \
# countryname
# Afghanistan                      556.302002                          0.082079
# Albania                         4531.020806                          3.897711
# Algeria                         4044.276600                         -0.750500
# Angola                          4095.812942                         -3.409903
# Argentina                      14591.863380                          1.609282
#
# indicatorname  Incidence of tuberculosis (per 100,000 people)  ...  \
# countryname                                                    ...
# Afghanistan                                             189.0  ...
# Albania                                                  20.0  ...
# Algeria                                                  70.0  ...
# Angola                                                  359.0  ...
# Argentina                                                27.0  ...
#
# indicatorname  Lifetime risk of maternal death (%)  \
# countryname
# Afghanistan                               3.063593
# Albania                                   0.026286
# Algeria                                   0.368716
# Angola                                    1.451251
# Argentina                                 0.091957
#
# indicatorname  Mobile cellular subscriptions (per 100 people)  \
# countryname
# Afghanistan                                         65.929134
# Albania                                            125.710352
# Algeria                                            110.767246
# Angola                                              44.686107
# Argentina                                          140.877124
#
# indicatorname  Mortality rate, infant (per 1,000 live births)  Net migration  \
# countryname
# Afghanistan                                              49.5      -314602.0
# Albania                                                   8.0       -69998.0
# Algeria                                                  20.6       -50002.0
# Angola                                                   53.4        32066.0
# Argentina                                                 9.3        24000.0
#
# indicatorname  Rural population (% of total population)  \
# countryname
# Afghanistan                                      74.750
# Albania                                          40.617
# Algeria                                          27.948
# Angola                                           35.161
# Argentina                                         8.251
#
# indicatorname  Secure Internet servers (per 1 million people)  \
# countryname
# Afghanistan                                         43.447835
# Albania                                            443.020376
# Algeria                                             63.325702
# Angola                                              10.799300
# Argentina                                         1628.591391
#
# indicatorname  Survival to age 65, female (% of cohort)  \
# countryname
# Afghanistan                                   67.574376
# Albania                                       91.145395
# Algeria                                       85.829405
# Angola                                        63.665746
# Argentina                                     86.900558
#
# indicatorname  Survival to age 65, male (% of cohort)  \
# countryname
# Afghanistan                                 60.950303
# Albania                                     84.702788
# Algeria                                     81.889538
# Angola                                      50.634695
# Argentina                                   76.722114
#
# indicatorname  Tuberculosis case detection rate (%, all forms)  \
# countryname
# Afghanistan                                               68.0
# Albania                                                   87.0
# Algeria                                                   80.0
# Angola                                                    51.0
# Argentina                                                 87.0
#
# indicatorname  Urban population (% of total population)
# countryname
# Afghanistan                                      25.250
# Albania                                          59.383
# Algeria                                          72.052
# Angola                                           64.839
# Argentina                                        91.749
#
# [5 rows x 25 columns]

# %%
pivot_df=pivot_df.dropna(how='any')

# %%
pivot_df.count()
# Out:
# indicatorname
# Birth rate, crude (per 1,000 people)                                                             149
# Employment in agriculture (% of total employment) (modeled ILO estimate)                         149
# Employment in agriculture, female (% of female employment) (modeled ILO estimate)                149
# Employment in industry, female (% of female employment) (modeled ILO estimate)                   149
# Employment in services, female (% of female employment) (modeled ILO estimate)                   149
# Employment to population ratio, 15+, male (%) (modeled ILO estimate)                             149
# Fixed telephone subscriptions (per 100 people)                                                   149
# GDP per capita (current US$)                                                                     149
# GDP per capita growth (annual %)                                                                 149
# Incidence of tuberculosis (per 100,000 people)                                                   149
# Individuals using the Internet (% of population)                                                 149
# Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)    149
# Life expectancy at birth, female (years)                                                         149
# Life expectancy at birth, male (years)                                                           149
# Life expectancy at birth, total (years)                                                          149
# Lifetime risk of maternal death (%)                                                              149
# Mobile cellular subscriptions (per 100 people)                                                   149
# Mortality rate, infant (per 1,000 live births)                                                   149
# Net migration                                                                                    149
# Rural population (% of total population)                                                         149
# Secure Internet servers (per 1 million people)                                                   149
# Survival to age 65, female (% of cohort)                                                         149
# Survival to age 65, male (% of cohort)                                                           149
# Tuberculosis case detection rate (%, all forms)                                                  149
# Urban population (% of total population)                                                         149
# dtype: int64

# %%
target_groups_df = pd.read_sql("SELECT distinct countryname,target_groups  from table9_2017", connection)
                              
target_groups_df.head()
# Out:
#    countryname     target_groups
# 0     Thailand   Extremely Happy
# 1         Iraq    Moderately Sad
# 2       Angola          Very Sad
# 3      Ireland   Extremely Happy
# 4  El Salvador  Moderately Happy

# %%
merged_df = pd.merge(pivot_df, target_groups_df 
                   ,left_on="countryname"
                   ,right_on = "countryname"
                   ,how="inner")

# %%
merged_df.head()
# Out:
#    countryname  Birth rate, crude (per 1,000 people)  \
# 0  Afghanistan                                33.211
# 1      Albania                                11.934
# 2      Algeria                                24.846
# 3       Angola                                41.281
# 4    Argentina                                17.205
#
#    Employment in agriculture (% of total employment) (modeled ILO estimate)  \
# 0                                          43.988998
# 1                                          38.203999
# 2                                          10.160000
# 3                                          50.557999
# 4                                           0.059000
#
#    Employment in agriculture, female (% of female employment) (modeled ILO estimate)  \
# 0                                          66.218002
# 1                                          42.542000
# 2                                           3.841000
# 3                                          56.988998
# 4                                           0.015000
#
#    Employment in industry, female (% of female employment) (modeled ILO estimate)  \
# 0                                          24.278999
# 1                                          15.132000
# 2                                          24.360001
# 3                                           1.134000
# 4                                           9.166000
#
#    Employment in services, female (% of female employment) (modeled ILO estimate)  \
# 0                                           9.504000
# 1                                          42.325001
# 2                                          71.799004
# 3                                          41.877998
# 4                                          90.819000
#
#    Employment to population ratio, 15+, male (%) (modeled ILO estimate)  \
# 0                                          66.950996
# 1                                          55.379002
# 2                                          60.862000
# 3                                          73.719002
# 4                                          67.257004
#
#    Fixed telephone subscriptions (per 100 people)  \
# 0                                        0.327222
# 1                                        8.554284
# 2                                        9.908341
# 3                                        0.540199
# 4                                       22.177975
#
#    GDP per capita (current US$)  GDP per capita growth (annual %)  ...  \
# 0                    556.302002                          0.082079  ...
# 1                   4531.020806                          3.897711  ...
# 2                   4044.276600                         -0.750500  ...
# 3                   4095.812942                         -3.409903  ...
# 4                  14591.863380                          1.609282  ...
#
#    Mobile cellular subscriptions (per 100 people)  \
# 0                                       65.929134
# 1                                      125.710352
# 2                                      110.767246
# 3                                       44.686107
# 4                                      140.877124
#
#    Mortality rate, infant (per 1,000 live births)  Net migration  \
# 0                                            49.5      -314602.0
# 1                                             8.0       -69998.0
# 2                                            20.6       -50002.0
# 3                                            53.4        32066.0
# 4                                             9.3        24000.0
#
#    Rural population (% of total population)  \
# 0                                    74.750
# 1                                    40.617
# 2                                    27.948
# 3                                    35.161
# 4                                     8.251
#
#    Secure Internet servers (per 1 million people)  \
# 0                                       43.447835
# 1                                      443.020376
# 2                                       63.325702
# 3                                       10.799300
# 4                                     1628.591391
#
#    Survival to age 65, female (% of cohort)  \
# 0                                 67.574376
# 1                                 91.145395
# 2                                 85.829405
# 3                                 63.665746
# 4                                 86.900558
#
#    Survival to age 65, male (% of cohort)  \
# 0                               60.950303
# 1                               84.702788
# 2                               81.889538
# 3                               50.634695
# 4                               76.722114
#
#    Tuberculosis case detection rate (%, all forms)  \
# 0                                             68.0
# 1                                             87.0
# 2                                             80.0
# 3                                             51.0
# 4                                             87.0
#
#    Urban population (% of total population)     target_groups
# 0                                    25.250          Very Sad
# 1                                    59.383    Moderately Sad
# 2                                    72.052  Moderately Happy
# 3                                    64.839          Very Sad
# 4                                    91.749   Extremely Happy
#
# [5 rows x 27 columns]

# %%
target = merged_df["target_groups"]
target.head()
# Out:
# 0            Very Sad
# 1      Moderately Sad
# 2    Moderately Happy
# 3            Very Sad
# 4     Extremely Happy
# Name: target_groups, dtype: object

# %%
target_names = pd.read_sql("SELECT distinct target_groups  from table9_2017", connection)
target_names
# Out:
#       target_groups
# 0   Extremely Happy
# 1         Apathetic
# 2  Moderately Happy
# 3    Moderately Sad
# 4          Very Sad

# %%
data = merged_df.drop(["target_groups","countryname"], axis=1)

# %%
feature_names = data.columns
data.head()
# Out:
#    Birth rate, crude (per 1,000 people)  \
# 0                                33.211
# 1                                11.934
# 2                                24.846
# 3                                41.281
# 4                                17.205
#
#    Employment in agriculture (% of total employment) (modeled ILO estimate)  \
# 0                                          43.988998
# 1                                          38.203999
# 2                                          10.160000
# 3                                          50.557999
# 4                                           0.059000
#
#    Employment in agriculture, female (% of female employment) (modeled ILO estimate)  \
# 0                                          66.218002
# 1                                          42.542000
# 2                                           3.841000
# 3                                          56.988998
# 4                                           0.015000
#
#    Employment in industry, female (% of female employment) (modeled ILO estimate)  \
# 0                                          24.278999
# 1                                          15.132000
# 2                                          24.360001
# 3                                           1.134000
# 4                                           9.166000
#
#    Employment in services, female (% of female employment) (modeled ILO estimate)  \
# 0                                           9.504000
# 1                                          42.325001
# 2                                          71.799004
# 3                                          41.877998
# 4                                          90.819000
#
#    Employment to population ratio, 15+, male (%) (modeled ILO estimate)  \
# 0                                          66.950996
# 1                                          55.379002
# 2                                          60.862000
# 3                                          73.719002
# 4                                          67.257004
#
#    Fixed telephone subscriptions (per 100 people)  \
# 0                                        0.327222
# 1                                        8.554284
# 2                                        9.908341
# 3                                        0.540199
# 4                                       22.177975
#
#    GDP per capita (current US$)  GDP per capita growth (annual %)  \
# 0                    556.302002                          0.082079
# 1                   4531.020806                          3.897711
# 2                   4044.276600                         -0.750500
# 3                   4095.812942                         -3.409903
# 4                  14591.863380                          1.609282
#
#    Incidence of tuberculosis (per 100,000 people)  ...  \
# 0                                           189.0  ...
# 1                                            20.0  ...
# 2                                            70.0  ...
# 3                                           359.0  ...
# 4                                            27.0  ...
#
#    Lifetime risk of maternal death (%)  \
# 0                             3.063593
# 1                             0.026286
# 2                             0.368716
# 3                             1.451251
# 4                             0.091957
#
#    Mobile cellular subscriptions (per 100 people)  \
# 0                                       65.929134
# 1                                      125.710352
# 2                                      110.767246
# 3                                       44.686107
# 4                                      140.877124
#
#    Mortality rate, infant (per 1,000 live births)  Net migration  \
# 0                                            49.5      -314602.0
# 1                                             8.0       -69998.0
# 2                                            20.6       -50002.0
# 3                                            53.4        32066.0
# 4                                             9.3        24000.0
#
#    Rural population (% of total population)  \
# 0                                    74.750
# 1                                    40.617
# 2                                    27.948
# 3                                    35.161
# 4                                     8.251
#
#    Secure Internet servers (per 1 million people)  \
# 0                                       43.447835
# 1                                      443.020376
# 2                                       63.325702
# 3                                       10.799300
# 4                                     1628.591391
#
#    Survival to age 65, female (% of cohort)  \
# 0                                 67.574376
# 1                                 91.145395
# 2                                 85.829405
# 3                                 63.665746
# 4                                 86.900558
#
#    Survival to age 65, male (% of cohort)  \
# 0                               60.950303
# 1                               84.702788
# 2                               81.889538
# 3                               50.634695
# 4                               76.722114
#
#    Tuberculosis case detection rate (%, all forms)  \
# 0                                             68.0
# 1                                             87.0
# 2                                             80.0
# 3                                             51.0
# 4                                             87.0
#
#    Urban population (% of total population)
# 0                                    25.250
# 1                                    59.383
# 2                                    72.052
# 3                                    64.839
# 4                                    91.749
#
# [5 rows x 25 columns]

# %%
data.count()
# Out:
# Birth rate, crude (per 1,000 people)                                                             149
# Employment in agriculture (% of total employment) (modeled ILO estimate)                         149
# Employment in agriculture, female (% of female employment) (modeled ILO estimate)                149
# Employment in industry, female (% of female employment) (modeled ILO estimate)                   149
# Employment in services, female (% of female employment) (modeled ILO estimate)                   149
# Employment to population ratio, 15+, male (%) (modeled ILO estimate)                             149
# Fixed telephone subscriptions (per 100 people)                                                   149
# GDP per capita (current US$)                                                                     149
# GDP per capita growth (annual %)                                                                 149
# Incidence of tuberculosis (per 100,000 people)                                                   149
# Individuals using the Internet (% of population)                                                 149
# Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)    149
# Life expectancy at birth, female (years)                                                         149
# Life expectancy at birth, male (years)                                                           149
# Life expectancy at birth, total (years)                                                          149
# Lifetime risk of maternal death (%)                                                              149
# Mobile cellular subscriptions (per 100 people)                                                   149
# Mortality rate, infant (per 1,000 live births)                                                   149
# Net migration                                                                                    149
# Rural population (% of total population)                                                         149
# Secure Internet servers (per 1 million people)                                                   149
# Survival to age 65, female (% of cohort)                                                         149
# Survival to age 65, male (% of cohort)                                                           149
# Tuberculosis case detection rate (%, all forms)                                                  149
# Urban population (% of total population)                                                         149
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.42105263157894735

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.5526315789473685

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.06061726811523649, 'Life expectancy at birth, male (years)'),
#  (0.060124760494189335, 'Life expectancy at birth, total (years)'),
#  (0.058788553641558806,
#   'Employment in services, female (% of female employment) (modeled ILO estimate)'),
#  (0.05799367348528758, 'Life expectancy at birth, female (years)'),
#  (0.0574888753380035, 'GDP per capita (current US$)'),
#  (0.05002779407325834,
#   'Employment in agriculture, female (% of female employment) (modeled ILO estimate)'),
#  (0.04563324713226713, 'Survival to age 65, female (% of cohort)'),
#  (0.04517073199748583, 'Rural population (% of total population)'),
#  (0.041431029558620734, 'Mobile cellular subscriptions (per 100 people)'),
#  (0.04090882486703594,
#   'Employment in industry, female (% of female employment) (modeled ILO estimate)'),
#  (0.03839978476959044, 'Urban population (% of total population)'),
#  (0.037665376947660124, 'Mortality rate, infant (per 1,000 live births)'),
#  (0.03636356027854517, 'Incidence of tuberculosis (per 100,000 people)'),
#  (0.035587929177302115,
#   'Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)'),
#  (0.03531530973486504, 'Fixed telephone subscriptions (per 100 people)'),
#  (0.03366607607192699,
#   'Employment to population ratio, 15+, male (%) (modeled ILO estimate)'),
#  (0.03293810034502261, 'Survival to age 65, male (% of cohort)'),
#  (0.03278042109164395, 'Secure Internet servers (per 1 million people)'),
#  (0.03178775484963686, 'Individuals using the Internet (% of population)'),
#  (0.03117520603186293, 'Birth rate, crude (per 1,000 people)'),
#  (0.03041596026952014,
#   'Employment in agriculture (% of total employment) (modeled ILO estimate)'),
#  (0.02838971739930373, 'Lifetime risk of maternal death (%)'),
#  (0.026229710084151987, 'Tuberculosis case detection rate (%, all forms)'),
#  (0.02570718332164432, 'GDP per capita growth (annual %)'),
#  (0.025393150924380024, 'Net migration')]

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)


# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=25))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=5, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=60,
    shuffle=True,
    verbose=0
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-7e6f36f9ddc3> in <module>
#       7     epochs=60,
#       8     shuffle=True,
# ----> 9     verbose=0
#      10 )
#
# ~\Anaconda3\envs\PythonAdv\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# ~\Anaconda3\envs\PythonAdv\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     222           validation_data=validation_data,
#     223           validation_steps=validation_steps,
# --> 224           distribution_strategy=strategy)
#     225
#     226       total_samples = _get_total_number_of_samples(training_data_adapter)
#
# ~\Anaconda3\envs\PythonAdv\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in _process_training_inputs(model, x, y, batch_size, epochs, sample_weights, class_weights, steps_per_epoch, validation_split, validation_data, validation_steps, shuffle, distribution_strategy, max_queue_size, workers, use_multiprocessing)
#     545         max_queue_size=max_queue_size,
#     546         workers=workers,
# --> 547         use_multiprocessing=use_multiprocessing)
#     548     val_adapter = None
#     549     if validation_data:
#
# ~\Anaconda3\envs\PythonAdv\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in _process_inputs(model, x, y, batch_size, epochs, sample_weights, class_weights, shuffle, steps, distribution_strategy, max_queue_size, workers, use_multiprocessing)
#     592         batch_size=batch_size,
#     593         check_steps=False,
# --> 594         steps=steps)
#     595   adapter = adapter_cls(
#     596       x,
#
# ~\Anaconda3\envs\PythonAdv\lib\site-packages\tensorflow_core\python\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split, shuffle, extract_tensors_from_dataset)
#    2470           feed_input_shapes,
#    2471           check_batch_axis=False,  # Don't enforce the batch size.
# -> 2472           exception_prefix='input')
#    2473
#    2474     # Get typespecs for the input data and sanitize it if necessary.
#
# ~\Anaconda3\envs\PythonAdv\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     572                              ': expected ' + names[i] + ' to have shape ' +
#     573                              str(shape) + ' but got array with shape ' +
# --> 574                              str(data_shape))
#     575   return data
#     576
#
# ValueError: Error when checking input: expected dense_input to have shape (35,) but got array with shape (25,)

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
