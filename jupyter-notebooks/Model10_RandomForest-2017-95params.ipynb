# %%
from sklearn import tree
import pandas as pd
import os

# %%
# SQL Alchemy
from sqlalchemy import create_engine

# %%
# Create Engine for employee db
#engine = create_engine('postgres://sxwlsbsllohawb:4723d0dab89d2da6bf1aae12930fd6865874a185e4e4dca60e5af580ccd1a185@ec2-52-200-48-116.compute-1.amazonaws.com:5432/d7shhrp5hdjs4d')
engine = create_engine('postgresql://swain:db@localhost:5432/world_happiness')
connection = engine.connect()

# %%
indicators_df = pd.read_sql("SELECT * from table7_2017", connection)
                              
indicators_df.head()
# Out:
#    countryname                                      indicatorname  \
# 0  Afghanistan            Access to electricity (% of population)
# 1  Afghanistan   Adjusted savings: energy depletion (current US$)
# 2  Afghanistan  Adjusted savings: mineral depletion (current US$)
# 3  Afghanistan  Adolescent fertility rate (births per 1,000 wo...
# 4  Afghanistan  Age dependency ratio (% of working-age populat...
#
#       year_2017 target_groups
# 0  9.770000e+01      Very Sad
# 1  2.110297e+07      Very Sad
# 2  9.537887e+05      Very Sad
# 3  6.895700e+01      Very Sad
# 4  8.600075e+01      Very Sad

# %%
pivot_df = indicators_df.pivot(index='countryname', columns='indicatorname', values='year_2017')

# %%
pivot_df.head()
# Out:
# indicatorname  Access to electricity (% of population)  \
# countryname
# Afghanistan                                  97.700000
# Albania                                     100.000000
# Algeria                                     100.000000
# Angola                                       41.962894
# Argentina                                   100.000000
#
# indicatorname  Adjusted savings: energy depletion (current US$)  \
# countryname
# Afghanistan                                        2.110297e+07
# Albania                                            1.196189e+08
# Algeria                                            1.517693e+10
# Angola                                             1.497083e+10
# Argentina                                          4.903240e+09
#
# indicatorname  Adjusted savings: mineral depletion (current US$)  \
# countryname
# Afghanistan                                         9.537887e+05
# Albania                                             2.261126e+06
# Algeria                                             8.871101e+06
# Angola                                              0.000000e+00
# Argentina                                           1.431438e+09
#
# indicatorname  Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# countryname
# Afghanistan                                               68.957
# Albania                                                   19.642
# Algeria                                                   10.071
# Angola                                                   150.526
# Argentina                                                 62.782
#
# indicatorname  Age dependency ratio (% of working-age population)  \
# countryname
# Afghanistan                                            86.000753
# Albania                                                45.682097
# Algeria                                                55.804001
# Angola                                                 96.820228
# Argentina                                              56.046355
#
# indicatorname  Birth rate, crude (per 1,000 people)  \
# countryname
# Afghanistan                                  33.211
# Albania                                      11.934
# Algeria                                      24.846
# Angola                                       41.281
# Argentina                                    17.205
#
# indicatorname  Contributing family workers, female (% of female employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            68.609001
# Albania                                                38.580002
# Algeria                                                 2.419000
# Angola                                                 10.554000
# Argentina                                               0.977000
#
# indicatorname  Contributing family workers, male (% of male employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            12.401000
# Albania                                                21.372999
# Algeria                                                 1.834000
# Angola                                                  7.986000
# Argentina                                               0.307000
#
# indicatorname  Contributing family workers, total (% of total employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                               23.763
# Albania                                                   28.600
# Algeria                                                    1.927
# Angola                                                     9.269
# Argentina                                                  0.587
#
# indicatorname  Death rate, crude (per 1,000 people)  ...  \
# countryname                                          ...
# Afghanistan                                   6.575  ...
# Albania                                       7.714  ...
# Algeria                                       4.717  ...
# Angola                                        8.432  ...
# Argentina                                     7.616  ...
#
# indicatorname  Unemployment, female (% of female labor force) (modeled ILO estimate)  \
# countryname
# Afghanistan                                               14.090
# Albania                                                   12.563
# Algeria                                                   21.114
# Angola                                                     7.467
# Argentina                                                  9.464
#
# indicatorname  Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# countryname
# Afghanistan                                               10.416
# Albania                                                   14.590
# Algeria                                                   10.021
# Angola                                                     6.769
# Argentina                                                  7.527
#
# indicatorname  Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# countryname
# Afghanistan                                               11.184
# Albania                                                   13.750
# Algeria                                                   11.996
# Angola                                                     7.119
# Argentina                                                  8.347
#
# indicatorname  Urban population  Urban population (% of total population)  \
# countryname
# Afghanistan           9164841.0                                    25.250
# Albania               1706345.0                                    59.383
# Algeria              29821745.0                                    72.052
# Angola               19332881.0                                    64.839
# Argentina            40410674.0                                    91.749
#
# indicatorname  Urban population growth (annual %)  \
# countryname
# Afghanistan                              3.463407
# Albania                                  1.541285
# Algeria                                  2.871374
# Angola                                   4.391957
# Argentina                                1.170196
#
# indicatorname  Wage and salaried workers, female (% of female employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                             7.551000
# Albania                                                44.298000
# Algeria                                                74.598999
# Angola                                                 17.445000
# Argentina                                              78.545998
#
# indicatorname  Wage and salaried workers, male (% of male employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            20.083000
# Albania                                                41.727001
# Algeria                                                67.067001
# Angola                                                 41.287998
# Argentina                                              71.865997
#
# indicatorname  Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            17.549999
# Albania                                                42.806999
# Algeria                                                68.268997
# Angola                                                 29.374001
# Argentina                                              74.660004
#
# indicatorname  Women Business and the Law Index Score (scale 1-100)
# countryname
# Afghanistan                                                 38.1
# Albania                                                     91.3
# Algeria                                                     57.5
# Angola                                                      73.1
# Argentina                                                   73.1
#
# [5 rows x 95 columns]

# %%
pivot_df=pivot_df.dropna(how='any')

# %%
pivot_df.count()
# Out:
# indicatorname
# Access to electricity (% of population)                                              89
# Adjusted savings: energy depletion (current US$)                                     89
# Adjusted savings: mineral depletion (current US$)                                    89
# Adolescent fertility rate (births per 1,000 women ages 15-19)                        89
# Age dependency ratio (% of working-age population)                                   89
#                                                                                      ..
# Urban population growth (annual %)                                                   89
# Wage and salaried workers, female (% of female employment) (modeled ILO estimate)    89
# Wage and salaried workers, male (% of male employment) (modeled ILO estimate)        89
# Wage and salaried workers, total (% of total employment) (modeled ILO estimate)      89
# Women Business and the Law Index Score (scale 1-100)                                 89
# Length: 95, dtype: int64

# %%
target_groups_df = pd.read_sql("SELECT distinct countryname,target_groups  from table7_2017", connection)
                              
target_groups_df.head()
# Out:
#   countryname    target_groups
# 0      Angola         Very Sad
# 1     Ireland  Extremely Happy
# 2      Malawi         Very Sad
# 3      Rwanda         Very Sad
# 4     Denmark  Extremely Happy

# %%
merged_df = pd.merge(pivot_df, target_groups_df 
                   ,left_on="countryname"
                   ,right_on = "countryname"
                   ,how="inner")

# %%
merged_df.head()
# Out:
#   countryname  Access to electricity (% of population)  \
# 0     Algeria                               100.000000
# 1      Angola                                41.962894
# 2     Armenia                               100.000000
# 3   Australia                               100.000000
# 4     Austria                               100.000000
#
#    Adjusted savings: energy depletion (current US$)  \
# 0                                      1.517693e+10
# 1                                      1.497083e+10
# 2                                      6.826427e-01
# 3                                      9.940973e+09
# 4                                      1.947784e+08
#
#    Adjusted savings: mineral depletion (current US$)  \
# 0                                       8.871101e+06
# 1                                       0.000000e+00
# 2                                       3.519253e+08
# 3                                       2.256441e+10
# 4                                       1.451524e+07
#
#    Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                             10.071
# 1                                            150.526
# 2                                             21.490
# 3                                             11.715
# 4                                              7.340
#
#    Age dependency ratio (% of working-age population)  \
# 0                                          55.804001
# 1                                          96.820228
# 2                                          46.094267
# 3                                          52.599671
# 4                                          49.672586
#
#    Birth rate, crude (per 1,000 people)  \
# 0                                24.846
# 1                                41.281
# 2                                14.298
# 3                                12.600
# 4                                10.000
#
#    Contributing family workers, female (% of female employment) (modeled ILO estimate)  \
# 0                                              2.419
# 1                                             10.554
# 2                                              3.382
# 3                                              0.231
# 4                                              1.673
#
#    Contributing family workers, male (% of male employment) (modeled ILO estimate)  \
# 0                                              1.834
# 1                                              7.986
# 2                                              1.395
# 3                                              0.153
# 4                                              1.276
#
#    Contributing family workers, total (% of total employment) (modeled ILO estimate)  \
# 0                                              1.927
# 1                                              9.269
# 2                                              2.316
# 3                                              0.189
# 4                                              1.462
#
#    ...  Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# 0  ...                                             10.021
# 1  ...                                              6.769
# 2  ...                                             17.906
# 3  ...                                              5.525
# 4  ...                                              5.908
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                             11.996
# 1                                              7.119
# 2                                             17.705
# 3                                              5.591
# 4                                              5.499
#
#    Urban population  Urban population (% of total population)  \
# 0        29821745.0                                    72.052
# 1        19332881.0                                    64.839
# 2         1858263.0                                    63.103
# 3        21133982.0                                    85.904
# 4         5110858.0                                    58.094
#
#    Urban population growth (annual %)  \
# 0                            2.871374
# 1                            4.391957
# 2                            0.327886
# 3                            1.805664
# 4                            1.020479
#
#    Wage and salaried workers, female (% of female employment) (modeled ILO estimate)  \
# 0                                          74.598999
# 1                                          17.445000
# 2                                          60.888000
# 3                                          87.560997
# 4                                          90.158997
#
#    Wage and salaried workers, male (% of male employment) (modeled ILO estimate)  \
# 0                                          67.067001
# 1                                          41.287998
# 2                                          58.601002
# 3                                          79.254997
# 4                                          85.387001
#
#    Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  \
# 0                                          68.268997
# 1                                          29.374001
# 2                                          59.660999
# 3                                          83.100998
# 4                                          87.623001
#
#    Women Business and the Law Index Score (scale 1-100)     target_groups
# 0                                               57.5     Moderately Happy
# 1                                               73.1             Very Sad
# 2                                               80.0       Moderately Sad
# 3                                               96.9      Extremely Happy
# 4                                               94.4      Extremely Happy
#
# [5 rows x 97 columns]

# %%
target = merged_df["target_groups"]
target.head()
# Out:
# 0    Moderately Happy
# 1            Very Sad
# 2      Moderately Sad
# 3     Extremely Happy
# 4     Extremely Happy
# Name: target_groups, dtype: object

# %%
target_names = pd.read_sql("SELECT distinct target_groups  from table7_2017", connection)
target_names
# Out:
#       target_groups
# 0   Extremely Happy
# 1         Apathetic
# 2  Moderately Happy
# 3    Moderately Sad
# 4          Very Sad

# %%
data = merged_df.drop(["target_groups","countryname"], axis=1)

# %%
feature_names = data.columns
data.head()
# Out:
#    Access to electricity (% of population)  \
# 0                               100.000000
# 1                                41.962894
# 2                               100.000000
# 3                               100.000000
# 4                               100.000000
#
#    Adjusted savings: energy depletion (current US$)  \
# 0                                      1.517693e+10
# 1                                      1.497083e+10
# 2                                      6.826427e-01
# 3                                      9.940973e+09
# 4                                      1.947784e+08
#
#    Adjusted savings: mineral depletion (current US$)  \
# 0                                       8.871101e+06
# 1                                       0.000000e+00
# 2                                       3.519253e+08
# 3                                       2.256441e+10
# 4                                       1.451524e+07
#
#    Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                             10.071
# 1                                            150.526
# 2                                             21.490
# 3                                             11.715
# 4                                              7.340
#
#    Age dependency ratio (% of working-age population)  \
# 0                                          55.804001
# 1                                          96.820228
# 2                                          46.094267
# 3                                          52.599671
# 4                                          49.672586
#
#    Birth rate, crude (per 1,000 people)  \
# 0                                24.846
# 1                                41.281
# 2                                14.298
# 3                                12.600
# 4                                10.000
#
#    Contributing family workers, female (% of female employment) (modeled ILO estimate)  \
# 0                                              2.419
# 1                                             10.554
# 2                                              3.382
# 3                                              0.231
# 4                                              1.673
#
#    Contributing family workers, male (% of male employment) (modeled ILO estimate)  \
# 0                                              1.834
# 1                                              7.986
# 2                                              1.395
# 3                                              0.153
# 4                                              1.276
#
#    Contributing family workers, total (% of total employment) (modeled ILO estimate)  \
# 0                                              1.927
# 1                                              9.269
# 2                                              2.316
# 3                                              0.189
# 4                                              1.462
#
#    Death rate, crude (per 1,000 people)  ...  \
# 0                                 4.717  ...
# 1                                 8.432  ...
# 2                                 9.862  ...
# 3                                 6.500  ...
# 4                                 9.500  ...
#
#    Unemployment, female (% of female labor force) (modeled ILO estimate)  \
# 0                                          21.114000
# 1                                           7.467000
# 2                                          17.471001
# 3                                           5.668000
# 4                                           5.031000
#
#    Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# 0                                             10.021
# 1                                              6.769
# 2                                             17.906
# 3                                              5.525
# 4                                              5.908
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                             11.996
# 1                                              7.119
# 2                                             17.705
# 3                                              5.591
# 4                                              5.499
#
#    Urban population  Urban population (% of total population)  \
# 0        29821745.0                                    72.052
# 1        19332881.0                                    64.839
# 2         1858263.0                                    63.103
# 3        21133982.0                                    85.904
# 4         5110858.0                                    58.094
#
#    Urban population growth (annual %)  \
# 0                            2.871374
# 1                            4.391957
# 2                            0.327886
# 3                            1.805664
# 4                            1.020479
#
#    Wage and salaried workers, female (% of female employment) (modeled ILO estimate)  \
# 0                                          74.598999
# 1                                          17.445000
# 2                                          60.888000
# 3                                          87.560997
# 4                                          90.158997
#
#    Wage and salaried workers, male (% of male employment) (modeled ILO estimate)  \
# 0                                          67.067001
# 1                                          41.287998
# 2                                          58.601002
# 3                                          79.254997
# 4                                          85.387001
#
#    Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  \
# 0                                          68.268997
# 1                                          29.374001
# 2                                          59.660999
# 3                                          83.100998
# 4                                          87.623001
#
#    Women Business and the Law Index Score (scale 1-100)
# 0                                               57.5
# 1                                               73.1
# 2                                               80.0
# 3                                               96.9
# 4                                               94.4
#
# [5 rows x 95 columns]

# %%
data.count()
# Out:
# Access to electricity (% of population)                                              89
# Adjusted savings: energy depletion (current US$)                                     89
# Adjusted savings: mineral depletion (current US$)                                    89
# Adolescent fertility rate (births per 1,000 women ages 15-19)                        89
# Age dependency ratio (% of working-age population)                                   89
#                                                                                      ..
# Urban population growth (annual %)                                                   89
# Wage and salaried workers, female (% of female employment) (modeled ILO estimate)    89
# Wage and salaried workers, male (% of male employment) (modeled ILO estimate)        89
# Wage and salaried workers, total (% of total employment) (modeled ILO estimate)      89
# Women Business and the Law Index Score (scale 1-100)                                 89
# Length: 95, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.34782608695652173

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.5652173913043478

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.03206198586988601, 'Rural population (% of total population)'),
#  (0.029731929962900576, 'Mortality rate, infant (per 1,000 live births)'),
#  (0.02963488227237843,
#   'Employment in services, female (% of female employment) (modeled ILO estimate)'),
#  (0.026225916178586547, 'Survival to age 65, male (% of cohort)'),
#  (0.025921595798845877, 'Physicians (per 1,000 people)'),
#  (0.024998113829304634, 'Urban population (% of total population)'),
#  (0.02489148640706641, 'Life expectancy at birth, male (years)'),
#  (0.024161744519655533, 'Life expectancy at birth, total (years)'),
#  (0.023511973591392458, 'GDP per capita (current US$)'),
#  (0.022092316020944986, 'Life expectancy at birth, female (years)'),
#  (0.021793449075261217,
#   'Employment in agriculture, female (% of female employment) (modeled ILO estimate)'),
#  (0.019806547944204066,
#   'Employment in agriculture, male (% of male employment) (modeled ILO estimate)'),
#  (0.019191057383803327, 'Urban population growth (annual %)'),
#  (0.01824715267522858,
#   'Employment in agriculture (% of total employment) (modeled ILO estimate)'),
#  (0.01756537742233647, 'Survival to age 65, female (% of cohort)'),
#  (0.016167313764034918, 'Net migration'),
#  (0.0160943148523505, 'Secure Internet servers (per 1 million people)'),
#  (0.015858542666492406, 'Individuals using the Internet (% of population)'),
#  (0.015292727546760334, 'Fertility rate, total (births per woman)'),
#  (0.014769728747571981, 'Population growth (annual %)'),
#  (0.013569104608857765, 'Tuberculosis case detection rate (%, all forms)'),
#  (0.01284537670654885, 'Birth rate, crude (per 1,000 people)'),
#  (0.012825658958259574, 'GDP per capita growth (annual %)'),
#  (0.01249204674941946,
#   'Contributing family workers, female (% of female employment) (modeled ILO estimate)'),
#  (0.012196453755334395,
#   'Employment to population ratio, 15+, male (%) (modeled ILO estimate)'),
#  (0.011838578805082567,
#   'Contributing family workers, total (% of total employment) (modeled ILO estimate)'),
#  (0.011699527917279405,
#   'Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)'),
#  (0.011634711390030347, 'Incidence of tuberculosis (per 100,000 people)'),
#  (0.011054847153421666,
#   'Employment in industry, female (% of female employment) (modeled ILO estimate)'),
#  (0.01092218251205437,
#   'Self-employed, female (% of female employment) (modeled ILO estimate)'),
#  (0.010326950304854816, 'Age dependency ratio (% of working-age population)'),
#  (0.010180560166863634,
#   'Self-employed, total (% of total employment) (modeled ILO estimate)'),
#  (0.010075548971768641,
#   'Contributing family workers, male (% of male employment) (modeled ILO estimate)'),
#  (0.009970877603653781, 'Labor force, female (% of total labor force)'),
#  (0.009906573176204721, 'Lifetime risk of maternal death (%)'),
#  (0.009704335039955424, 'Public credit registry coverage (% of adults)'),
#  (0.009695713159404715,
#   'Maternal mortality ratio (modeled estimate, per 100,000 live births)'),
#  (0.009546656162987568, 'Mobile cellular subscriptions (per 100 people)'),
#  (0.009320270727569946, 'Fixed telephone subscriptions (per 100 people)'),
#  (0.009207283356252122,
#   'Merchandise imports by the reporting economy (current US$)'),
#  (0.009196044709255306,
#   'Employment in services (% of total employment) (modeled ILO estimate)'),
#  (0.009109262993137827,
#   'Employment to population ratio, 15+, total (%) (modeled ILO estimate)'),
#  (0.00894561738359927,
#   'Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate)'),
#  (0.008885424069862912, 'GDP growth (annual %)'),
#  (0.008851567293754033, 'Access to electricity (% of population)'),
#  (0.008781305108787402,
#   'Wage and salaried workers, total (% of total employment) (modeled ILO estimate)'),
#  (0.008760458355208844, 'Population, female'),
#  (0.008279976136491774, 'Foreign direct investment, net inflows (% of GDP)'),
#  (0.008209753713078864, 'Population, male (% of total population)'),
#  (0.008166616684264492,
#   'Merchandise imports from high-income economies (% of total merchandise imports)'),
#  (0.008048530819620425, 'Labor force, total'),
#  (0.007939760277628525,
#   'Adolescent fertility rate (births per 1,000 women ages 15-19)'),
#  (0.00789957159168732, 'Fixed telephone subscriptions'),
#  (0.007883321728705957,
#   'Merchandise exports to high-income economies (% of total merchandise exports)'),
#  (0.007612270234052784, 'Population, female (% of total population)'),
#  (0.007503660805729,
#   'Ease of doing business score (0 = lowest performance to 100 = best performance)'),
#  (0.007484449114728363,
#   'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'),
#  (0.0074386802682178425,
#   'Wage and salaried workers, male (% of male employment) (modeled ILO estimate)'),
#  (0.00727749685710971, 'Inflation, consumer prices (annual %)'),
#  (0.00720361752818568, 'Secure Internet servers'),
#  (0.007150202314912477,
#   'Self-employed, male (% of male employment) (modeled ILO estimate)'),
#  (0.007009504896969615, 'Private credit bureau coverage (% of adults)'),
#  (0.006993644845096621,
#   'Merchandise exports by the reporting economy, residual (% of total merchandise exports)'),
#  (0.00690142669568219, 'Population, male'),
#  (0.006693304423049872,
#   'Women Business and the Law Index Score (scale 1-100)'),
#  (0.006681472424422632,
#   'Unemployment, total (% of total labor force) (modeled ILO estimate)'),
#  (0.006628538435754669,
#   'Employers, male (% of male employment) (modeled ILO estimate)'),
#  (0.006468471907816686,
#   'Wage and salaried workers, female (% of female employment) (modeled ILO estimate)'),
#  (0.006257762728392508,
#   'Employment in industry, male (% of male employment) (modeled ILO estimate)'),
#  (0.006066192233029384,
#   'Merchandise imports by the reporting economy, residual (% of total merchandise imports)'),
#  (0.006038905594625738, 'Urban population'),
#  (0.006035016236036017, 'Inflation, GDP deflator (annual %)'),
#  (0.005927721993506184,
#   'Employment in services, male (% of male employment) (modeled ILO estimate)'),
#  (0.0057308603638474035,
#   'Unemployment, female (% of female labor force) (modeled ILO estimate)'),
#  (0.00568345935818373,
#   'Employment to population ratio, 15+, female (%) (modeled ILO estimate)'),
#  (0.005678205086569177, 'GDP (current US$)'),
#  (0.005667317097249363,
#   'Unemployment, male (% of male labor force) (modeled ILO estimate)'),
#  (0.005540592153894526,
#   'Employment in industry (% of total employment) (modeled ILO estimate)'),
#  (0.0055273312011892605,
#   'Employers, total (% of total employment) (modeled ILO estimate)'),
#  (0.005527194949474591,
#   'Employers, female (% of female employment) (modeled ILO estimate)'),
#  (0.005483784418892393,
#   'Merchandise exports by the reporting economy (current US$)'),
#  (0.005367103954100997,
#   'Ratio of female to male labor force participation rate (%) (modeled ILO estimate)'),
#  (0.005116694966253692, 'Population, total'),
#  (0.004874973618234148, 'Adjusted savings: mineral depletion (current US$)'),
#  (0.004648822319112464, 'Adjusted savings: energy depletion (current US$)'),
#  (0.004640280883238621,
#   'Strength of legal rights index (0=weak to 12=strong)'),
#  (0.004452516107532551, 'Sex ratio at birth (male births per female births)'),
#  (0.0042274202144774575, 'Mobile cellular subscriptions'),
#  (0.0037206949414926318, 'Lower secondary school starting age (years)'),
#  (0.0036626761003785095, 'Death rate, crude (per 1,000 people)'),
#  (0.0036215757805370713, 'Time required to start a business (days)'),
#  (0.0021704182255443726,
#   'Depth of credit information index (0=low to 8=high)'),
#  (0.0014917786716896516, 'Secondary education, duration (years)'),
#  (0.0010649800972979413, 'Primary education, duration (years)'),
#  (0.0007403553335995017, 'Primary school starting age (years)')]
