# %%
from sklearn import tree
import pandas as pd
import os

# %%
# SQL Alchemy
from sqlalchemy import create_engine

# %%
# Create Engine for employee db
#engine = create_engine('postgres://sxwlsbsllohawb:4723d0dab89d2da6bf1aae12930fd6865874a185e4e4dca60e5af580ccd1a185@ec2-52-200-48-116.compute-1.amazonaws.com:5432/d7shhrp5hdjs4d')
engine = create_engine('postgresql://swain:db@localhost:5432/world_happiness')
connection = engine.connect()

# %%
indicators_df = pd.read_sql("SELECT * from table9_2017", connection)
                              
indicators_df.head()
# Out:
#    countryname                                      indicatorname  year_2017  \
# 0  Afghanistan               Birth rate, crude (per 1,000 people)  33.211000
# 1  Afghanistan  Employment in agriculture (% of total employme...  43.988998
# 2  Afghanistan  Employment in agriculture, female (% of female...  66.218002
# 3  Afghanistan  Employment in industry, female (% of female em...  24.278999
# 4  Afghanistan  Employment in services, female (% of female em...   9.504000
#
#   target_groups
# 0      Very Sad
# 1      Very Sad
# 2      Very Sad
# 3      Very Sad
# 4      Very Sad

# %%
pivot_df = indicators_df.pivot(index='countryname', columns='indicatorname', values='year_2017')

# %%
pivot_df.head()
# Out:
# indicatorname  Birth rate, crude (per 1,000 people)  \
# countryname
# Afghanistan                                  33.211
# Albania                                      11.934
# Algeria                                      24.846
# Angola                                       41.281
# Argentina                                    17.205
#
# indicatorname  Employment in agriculture (% of total employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            43.988998
# Albania                                                38.203999
# Algeria                                                10.160000
# Angola                                                 50.557999
# Argentina                                               0.059000
#
# indicatorname  Employment in agriculture, female (% of female employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            66.218002
# Albania                                                42.542000
# Algeria                                                 3.841000
# Angola                                                 56.988998
# Argentina                                               0.015000
#
# indicatorname  Employment in industry, female (% of female employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            24.278999
# Albania                                                15.132000
# Algeria                                                24.360001
# Angola                                                  1.134000
# Argentina                                               9.166000
#
# indicatorname  Employment in services, female (% of female employment) (modeled ILO estimate)  \
# countryname
# Afghanistan                                             9.504000
# Albania                                                42.325001
# Algeria                                                71.799004
# Angola                                                 41.877998
# Argentina                                              90.819000
#
# indicatorname  Employment to population ratio, 15+, male (%) (modeled ILO estimate)  \
# countryname
# Afghanistan                                            66.950996
# Albania                                                55.379002
# Algeria                                                60.862000
# Angola                                                 73.719002
# Argentina                                              67.257004
#
# indicatorname  Fixed telephone subscriptions (per 100 people)  \
# countryname
# Afghanistan                                          0.327222
# Albania                                              8.554284
# Algeria                                              9.908341
# Angola                                               0.540199
# Argentina                                           22.177975
#
# indicatorname  GDP per capita (current US$)  GDP per capita growth (annual %)  \
# countryname
# Afghanistan                      556.302002                          0.082079
# Albania                         4531.020806                          3.897711
# Algeria                         4044.276600                         -0.750500
# Angola                          4095.812942                         -3.409903
# Argentina                      14591.863380                          1.609282
#
# indicatorname  Incidence of tuberculosis (per 100,000 people)  ...  \
# countryname                                                    ...
# Afghanistan                                             189.0  ...
# Albania                                                  20.0  ...
# Algeria                                                  70.0  ...
# Angola                                                  359.0  ...
# Argentina                                                27.0  ...
#
# indicatorname  Lifetime risk of maternal death (%)  \
# countryname
# Afghanistan                               3.063593
# Albania                                   0.026286
# Algeria                                   0.368716
# Angola                                    1.451251
# Argentina                                 0.091957
#
# indicatorname  Mobile cellular subscriptions (per 100 people)  \
# countryname
# Afghanistan                                         65.929134
# Albania                                            125.710352
# Algeria                                            110.767246
# Angola                                              44.686107
# Argentina                                          140.877124
#
# indicatorname  Mortality rate, infant (per 1,000 live births)  Net migration  \
# countryname
# Afghanistan                                              49.5      -314602.0
# Albania                                                   8.0       -69998.0
# Algeria                                                  20.6       -50002.0
# Angola                                                   53.4        32066.0
# Argentina                                                 9.3        24000.0
#
# indicatorname  Rural population (% of total population)  \
# countryname
# Afghanistan                                      74.750
# Albania                                          40.617
# Algeria                                          27.948
# Angola                                           35.161
# Argentina                                         8.251
#
# indicatorname  Secure Internet servers (per 1 million people)  \
# countryname
# Afghanistan                                         43.447835
# Albania                                            443.020376
# Algeria                                             63.325702
# Angola                                              10.799300
# Argentina                                         1628.591391
#
# indicatorname  Survival to age 65, female (% of cohort)  \
# countryname
# Afghanistan                                   67.574376
# Albania                                       91.145395
# Algeria                                       85.829405
# Angola                                        63.665746
# Argentina                                     86.900558
#
# indicatorname  Survival to age 65, male (% of cohort)  \
# countryname
# Afghanistan                                 60.950303
# Albania                                     84.702788
# Algeria                                     81.889538
# Angola                                      50.634695
# Argentina                                   76.722114
#
# indicatorname  Tuberculosis case detection rate (%, all forms)  \
# countryname
# Afghanistan                                               68.0
# Albania                                                   87.0
# Algeria                                                   80.0
# Angola                                                    51.0
# Argentina                                                 87.0
#
# indicatorname  Urban population (% of total population)
# countryname
# Afghanistan                                      25.250
# Albania                                          59.383
# Algeria                                          72.052
# Angola                                           64.839
# Argentina                                        91.749
#
# [5 rows x 25 columns]

# %%
pivot_df=pivot_df.dropna(how='any')

# %%
pivot_df.count()
# Out:
# indicatorname
# Birth rate, crude (per 1,000 people)                                                             149
# Employment in agriculture (% of total employment) (modeled ILO estimate)                         149
# Employment in agriculture, female (% of female employment) (modeled ILO estimate)                149
# Employment in industry, female (% of female employment) (modeled ILO estimate)                   149
# Employment in services, female (% of female employment) (modeled ILO estimate)                   149
# Employment to population ratio, 15+, male (%) (modeled ILO estimate)                             149
# Fixed telephone subscriptions (per 100 people)                                                   149
# GDP per capita (current US$)                                                                     149
# GDP per capita growth (annual %)                                                                 149
# Incidence of tuberculosis (per 100,000 people)                                                   149
# Individuals using the Internet (% of population)                                                 149
# Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)    149
# Life expectancy at birth, female (years)                                                         149
# Life expectancy at birth, male (years)                                                           149
# Life expectancy at birth, total (years)                                                          149
# Lifetime risk of maternal death (%)                                                              149
# Mobile cellular subscriptions (per 100 people)                                                   149
# Mortality rate, infant (per 1,000 live births)                                                   149
# Net migration                                                                                    149
# Rural population (% of total population)                                                         149
# Secure Internet servers (per 1 million people)                                                   149
# Survival to age 65, female (% of cohort)                                                         149
# Survival to age 65, male (% of cohort)                                                           149
# Tuberculosis case detection rate (%, all forms)                                                  149
# Urban population (% of total population)                                                         149
# dtype: int64

# %%
target_groups_df = pd.read_sql("SELECT distinct countryname,target_groups  from table9_2017", connection)
                              
target_groups_df.head()
# Out:
#    countryname     target_groups
# 0     Thailand   Extremely Happy
# 1         Iraq    Moderately Sad
# 2       Angola          Very Sad
# 3      Ireland   Extremely Happy
# 4  El Salvador  Moderately Happy

# %%
merged_df = pd.merge(pivot_df, target_groups_df 
                   ,left_on="countryname"
                   ,right_on = "countryname"
                   ,how="inner")

# %%
merged_df.head()
# Out:
#    countryname  Birth rate, crude (per 1,000 people)  \
# 0  Afghanistan                                33.211
# 1      Albania                                11.934
# 2      Algeria                                24.846
# 3       Angola                                41.281
# 4    Argentina                                17.205
#
#    Employment in agriculture (% of total employment) (modeled ILO estimate)  \
# 0                                          43.988998
# 1                                          38.203999
# 2                                          10.160000
# 3                                          50.557999
# 4                                           0.059000
#
#    Employment in agriculture, female (% of female employment) (modeled ILO estimate)  \
# 0                                          66.218002
# 1                                          42.542000
# 2                                           3.841000
# 3                                          56.988998
# 4                                           0.015000
#
#    Employment in industry, female (% of female employment) (modeled ILO estimate)  \
# 0                                          24.278999
# 1                                          15.132000
# 2                                          24.360001
# 3                                           1.134000
# 4                                           9.166000
#
#    Employment in services, female (% of female employment) (modeled ILO estimate)  \
# 0                                           9.504000
# 1                                          42.325001
# 2                                          71.799004
# 3                                          41.877998
# 4                                          90.819000
#
#    Employment to population ratio, 15+, male (%) (modeled ILO estimate)  \
# 0                                          66.950996
# 1                                          55.379002
# 2                                          60.862000
# 3                                          73.719002
# 4                                          67.257004
#
#    Fixed telephone subscriptions (per 100 people)  \
# 0                                        0.327222
# 1                                        8.554284
# 2                                        9.908341
# 3                                        0.540199
# 4                                       22.177975
#
#    GDP per capita (current US$)  GDP per capita growth (annual %)  ...  \
# 0                    556.302002                          0.082079  ...
# 1                   4531.020806                          3.897711  ...
# 2                   4044.276600                         -0.750500  ...
# 3                   4095.812942                         -3.409903  ...
# 4                  14591.863380                          1.609282  ...
#
#    Mobile cellular subscriptions (per 100 people)  \
# 0                                       65.929134
# 1                                      125.710352
# 2                                      110.767246
# 3                                       44.686107
# 4                                      140.877124
#
#    Mortality rate, infant (per 1,000 live births)  Net migration  \
# 0                                            49.5      -314602.0
# 1                                             8.0       -69998.0
# 2                                            20.6       -50002.0
# 3                                            53.4        32066.0
# 4                                             9.3        24000.0
#
#    Rural population (% of total population)  \
# 0                                    74.750
# 1                                    40.617
# 2                                    27.948
# 3                                    35.161
# 4                                     8.251
#
#    Secure Internet servers (per 1 million people)  \
# 0                                       43.447835
# 1                                      443.020376
# 2                                       63.325702
# 3                                       10.799300
# 4                                     1628.591391
#
#    Survival to age 65, female (% of cohort)  \
# 0                                 67.574376
# 1                                 91.145395
# 2                                 85.829405
# 3                                 63.665746
# 4                                 86.900558
#
#    Survival to age 65, male (% of cohort)  \
# 0                               60.950303
# 1                               84.702788
# 2                               81.889538
# 3                               50.634695
# 4                               76.722114
#
#    Tuberculosis case detection rate (%, all forms)  \
# 0                                             68.0
# 1                                             87.0
# 2                                             80.0
# 3                                             51.0
# 4                                             87.0
#
#    Urban population (% of total population)     target_groups
# 0                                    25.250          Very Sad
# 1                                    59.383    Moderately Sad
# 2                                    72.052  Moderately Happy
# 3                                    64.839          Very Sad
# 4                                    91.749   Extremely Happy
#
# [5 rows x 27 columns]

# %%
target = merged_df["target_groups"]
target.head()
# Out:
# 0            Very Sad
# 1      Moderately Sad
# 2    Moderately Happy
# 3            Very Sad
# 4     Extremely Happy
# Name: target_groups, dtype: object

# %%
target_names = pd.read_sql("SELECT distinct target_groups  from table9_2017", connection)
target_names
# Out:
#       target_groups
# 0   Extremely Happy
# 1         Apathetic
# 2  Moderately Happy
# 3    Moderately Sad
# 4          Very Sad

# %%
data = merged_df.drop(["target_groups","countryname"], axis=1)

# %%
feature_names = data.columns
data.head()
# Out:
#    Birth rate, crude (per 1,000 people)  \
# 0                                33.211
# 1                                11.934
# 2                                24.846
# 3                                41.281
# 4                                17.205
#
#    Employment in agriculture (% of total employment) (modeled ILO estimate)  \
# 0                                          43.988998
# 1                                          38.203999
# 2                                          10.160000
# 3                                          50.557999
# 4                                           0.059000
#
#    Employment in agriculture, female (% of female employment) (modeled ILO estimate)  \
# 0                                          66.218002
# 1                                          42.542000
# 2                                           3.841000
# 3                                          56.988998
# 4                                           0.015000
#
#    Employment in industry, female (% of female employment) (modeled ILO estimate)  \
# 0                                          24.278999
# 1                                          15.132000
# 2                                          24.360001
# 3                                           1.134000
# 4                                           9.166000
#
#    Employment in services, female (% of female employment) (modeled ILO estimate)  \
# 0                                           9.504000
# 1                                          42.325001
# 2                                          71.799004
# 3                                          41.877998
# 4                                          90.819000
#
#    Employment to population ratio, 15+, male (%) (modeled ILO estimate)  \
# 0                                          66.950996
# 1                                          55.379002
# 2                                          60.862000
# 3                                          73.719002
# 4                                          67.257004
#
#    Fixed telephone subscriptions (per 100 people)  \
# 0                                        0.327222
# 1                                        8.554284
# 2                                        9.908341
# 3                                        0.540199
# 4                                       22.177975
#
#    GDP per capita (current US$)  GDP per capita growth (annual %)  \
# 0                    556.302002                          0.082079
# 1                   4531.020806                          3.897711
# 2                   4044.276600                         -0.750500
# 3                   4095.812942                         -3.409903
# 4                  14591.863380                          1.609282
#
#    Incidence of tuberculosis (per 100,000 people)  ...  \
# 0                                           189.0  ...
# 1                                            20.0  ...
# 2                                            70.0  ...
# 3                                           359.0  ...
# 4                                            27.0  ...
#
#    Lifetime risk of maternal death (%)  \
# 0                             3.063593
# 1                             0.026286
# 2                             0.368716
# 3                             1.451251
# 4                             0.091957
#
#    Mobile cellular subscriptions (per 100 people)  \
# 0                                       65.929134
# 1                                      125.710352
# 2                                      110.767246
# 3                                       44.686107
# 4                                      140.877124
#
#    Mortality rate, infant (per 1,000 live births)  Net migration  \
# 0                                            49.5      -314602.0
# 1                                             8.0       -69998.0
# 2                                            20.6       -50002.0
# 3                                            53.4        32066.0
# 4                                             9.3        24000.0
#
#    Rural population (% of total population)  \
# 0                                    74.750
# 1                                    40.617
# 2                                    27.948
# 3                                    35.161
# 4                                     8.251
#
#    Secure Internet servers (per 1 million people)  \
# 0                                       43.447835
# 1                                      443.020376
# 2                                       63.325702
# 3                                       10.799300
# 4                                     1628.591391
#
#    Survival to age 65, female (% of cohort)  \
# 0                                 67.574376
# 1                                 91.145395
# 2                                 85.829405
# 3                                 63.665746
# 4                                 86.900558
#
#    Survival to age 65, male (% of cohort)  \
# 0                               60.950303
# 1                               84.702788
# 2                               81.889538
# 3                               50.634695
# 4                               76.722114
#
#    Tuberculosis case detection rate (%, all forms)  \
# 0                                             68.0
# 1                                             87.0
# 2                                             80.0
# 3                                             51.0
# 4                                             87.0
#
#    Urban population (% of total population)
# 0                                    25.250
# 1                                    59.383
# 2                                    72.052
# 3                                    64.839
# 4                                    91.749
#
# [5 rows x 25 columns]

# %%
data.count()
# Out:
# Birth rate, crude (per 1,000 people)                                                             149
# Employment in agriculture (% of total employment) (modeled ILO estimate)                         149
# Employment in agriculture, female (% of female employment) (modeled ILO estimate)                149
# Employment in industry, female (% of female employment) (modeled ILO estimate)                   149
# Employment in services, female (% of female employment) (modeled ILO estimate)                   149
# Employment to population ratio, 15+, male (%) (modeled ILO estimate)                             149
# Fixed telephone subscriptions (per 100 people)                                                   149
# GDP per capita (current US$)                                                                     149
# GDP per capita growth (annual %)                                                                 149
# Incidence of tuberculosis (per 100,000 people)                                                   149
# Individuals using the Internet (% of population)                                                 149
# Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)    149
# Life expectancy at birth, female (years)                                                         149
# Life expectancy at birth, male (years)                                                           149
# Life expectancy at birth, total (years)                                                          149
# Lifetime risk of maternal death (%)                                                              149
# Mobile cellular subscriptions (per 100 people)                                                   149
# Mortality rate, infant (per 1,000 live births)                                                   149
# Net migration                                                                                    149
# Rural population (% of total population)                                                         149
# Secure Internet servers (per 1 million people)                                                   149
# Survival to age 65, female (% of cohort)                                                         149
# Survival to age 65, male (% of cohort)                                                           149
# Tuberculosis case detection rate (%, all forms)                                                  149
# Urban population (% of total population)                                                         149
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
# Scale your data
# Import dependencies
from sklearn.preprocessing import LabelEncoder, MinMaxScaler,StandardScaler
from tensorflow.keras.utils import to_categorical

# scale the data
X_scaler =  MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train.values.ravel())
encoded_y_train = label_encoder.transform(y_train.values.ravel())
encoded_y_test = label_encoder.transform(y_test.values.ravel())

print(encoded_y_train)
print(encoded_y_test)
# Out:
# [1 3 1 1 3 2 3 4 4 1 2 2 3 1 2 4 1 0 1 0 0 3 2 3 1 4 3 3 3 4 1 3 2 3 1 0 3
#  3 3 0 3 3 0 3 0 1 4 1 2 1 2 2 1 2 1 4 2 0 2 0 3 4 0 1 2 2 1 0 4 2 3 1 2 3
#  2 1 4 0 4 2 1 0 2 0 3 3 1 0 2 4 0 1 1 1 4 3 4 1 1 2 2 2 3 2 4 3 3 1 4 0 0]
# [3 4 3 0 0 4 1 1 2 4 0 1 0 2 1 4 3 0 4 0 0 3 4 4 2 2 2 0 3 2 4 3 1 0 3 0 1
#  4]

# %%
# Support vector machine linear classifier
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train_scaled, encoded_y_train)
# Out:
# SVC(kernel='linear')

# %%
predictions = model.predict(X_test_scaled)
predictions
# Out:
# array([2, 2, 3, 3, 2, 3, 1, 1, 1, 4, 3, 1, 1, 1, 2, 3, 2, 2, 3, 3, 0, 3,
#        3, 3, 2, 0, 2, 3, 4, 2, 4, 3, 1, 2, 3, 3, 1, 4])

# %%
print(f"Training Data Score: {model.score(X_train_scaled, encoded_y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled, encoded_y_test)}")
# Out:
# Training Data Score: 0.6756756756756757
# Testing Data Score: 0.42105263157894735

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(encoded_y_test, predictions,
                           target_names =["Extremely Happy","Moderately Happy","Apathetic","Moderately Sad","Very Sad"]))
# Out:
#                   precision    recall  f1-score   support
#
#  Extremely Happy       0.50      0.10      0.17        10
# Moderately Happy       0.62      0.83      0.71         6
#        Apathetic       0.30      0.50      0.37         6
#   Moderately Sad       0.29      0.57      0.38         7
#         Very Sad       0.75      0.33      0.46         9
#
#         accuracy                           0.42        38
#        macro avg       0.49      0.47      0.42        38
#     weighted avg       0.51      0.42      0.40        38

# %%
# Create the GridSearchCV model
# Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10],
              'gamma': [0.0001, 0.001, 0.01]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Train the model with GridSearch
# Fit the model using the grid search estimator. 
# This will take the SVC model and try each combination of parameters
grid.fit(X_train_scaled, encoded_y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.478, total=   0.0s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.727, total=   0.0s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.591, total=   0.0s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.409, total=   0.0s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.455, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.478, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.727, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.591, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.409, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.455, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.478, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.727, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.591, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.409, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.455, total=   0.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.522, total=   0.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.682, total=   0.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.636, total=   0.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.455, total=   0.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.500, total=   0.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.522, total=   0.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.682, total=   0.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.636, total=   0.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.455, total=   0.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.500, total=   0.0s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ..................... C=5, gamma=0.01, score=0.522, total=   0.0s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ..................... C=5, gamma=0.01, score=0.682, total=   0.0s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ..................... C=5, gamma=0.01, score=0.636, total=   0.0s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ..................... C=5, gamma=0.01, score=0.455, total=   0.0s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ..................... C=5, gamma=0.01, score=0.500, total=   0.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.522, total=   0.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.636, total=   0.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.591, total=   0.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.318, total=   0.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.545, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [CV] ................... C=10, gamma=0.001, score=0.522, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.636, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.591, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.318, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.545, total=   0.0s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.522, total=   0.0s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.636, total=   0.0s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.591, total=   0.0s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.318, total=   0.0s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.545, total=   0.0s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:    0.1s finished
# GridSearchCV(estimator=SVC(kernel='linear'),
#              param_grid={'C': [1, 5, 10], 'gamma': [0.0001, 0.001, 0.01]},
#              verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 5, 'gamma': 0.0001}
# 0.5588932806324111

# %%
# Make predictions with the hypertuned model
predictions_tuned = grid.predict(X_test_scaled)

# %%
print('Test Acc: %.3f' % grid.score(X_test_scaled, encoded_y_test))
# Out:
# Test Acc: 0.474

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(encoded_y_test, predictions_tuned,
                           target_names =["Extremely Happy","Moderately Happy","Apathetic","Moderately Sad","Very Sad"]))
# Out:
#                   precision    recall  f1-score   support
#
#  Extremely Happy       0.67      0.20      0.31        10
# Moderately Happy       0.71      0.83      0.77         6
#        Apathetic       0.36      0.67      0.47         6
#   Moderately Sad       0.33      0.57      0.42         7
#         Very Sad       0.60      0.33      0.43         9
#
#         accuracy                           0.47        38
#        macro avg       0.54      0.52      0.48        38
#     weighted avg       0.55      0.47      0.46        38
